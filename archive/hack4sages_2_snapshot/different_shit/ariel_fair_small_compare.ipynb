# %% [markdown]
# # Fair Small-Data Ariel Comparison
#
# This notebook compares the actual `codex` Ariel quantum regressor against the actual `sota` FMPE model on the same small-data split.
#
# Fairness rules:
# - Both models use the exact same labeled `train`, `validation`, and `holdout` rows.
# - Each branch fits its own scalers using only the shared training rows.
# - Final comparison uses holdout RMSE, while validation RMSE is kept for model-selection context.

# %%
from __future__ import annotations

import importlib.util
import json
import os
import platform
import random
import shutil
import sys
from datetime import datetime
from pathlib import Path
import time

import numpy as np
import torch


def find_project_root(start: Path) -> Path:
    for candidate in [start, *start.parents]:
        if (candidate / "models" / "sbi_ariel_adc2023" / "train.py").exists():
            return candidate
        nested = candidate / "ariel" / "models" / "notebooks"
        if (nested / "models" / "sbi_ariel_adc2023" / "train.py").exists():
            return nested
    raise FileNotFoundError("Could not locate the Ariel notebook project root.")


PROJECT_ROOT = find_project_root(Path.cwd().resolve())
DATA_ROOT = PROJECT_ROOT.parent.parent
RUN_TAG = datetime.now().strftime("%Y%m%d_%H%M%S")
OUTPUT_ROOT = PROJECT_ROOT / "outputs" / "fair_small_compare" / RUN_TAG
OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

SEED = 42
TRAIN_ROWS = 256
VALIDATION_ROWS = 64
HOLDOUT_ROWS = 64

# Shared wall-clock budget for a genuinely runtime-constrained comparison.
FAIR_RUNTIME_BUDGET_SECONDS = 20.0
CODEX_STAGE1_BUDGET_SECONDS = 4.0

CODEX_QNN_QUBITS = 12
CODEX_QNN_DEPTH = 2
CODEX_DROPOUT = 0.05
CODEX_WEIGHT_DECAY = 1.0e-4
CODEX_GRADIENT_CLIP = 5.0
CODEX_QNN_INIT_SCALE = 0.1
CODEX_STAGE1_BATCH_SIZE = 64
CODEX_STAGE1_EVAL_BATCH_SIZE = 128
CODEX_STAGE1_MAX_EPOCHS = 50
CODEX_STAGE1_EARLY_STOP = 50
CODEX_STAGE1_SCHEDULER_PATIENCE = 6
CODEX_STAGE1_CLASSICAL_LR = 1.0e-3
CODEX_STAGE2_BATCH_SIZE = 16
CODEX_STAGE2_EVAL_BATCH_SIZE = 32
CODEX_STAGE2_MAX_EPOCHS = 50
CODEX_STAGE2_EARLY_STOP = 50
CODEX_STAGE2_SCHEDULER_PATIENCE = 6
CODEX_STAGE2_CLASSICAL_LR = 5.0e-5
CODEX_STAGE2_QUANTUM_LR = 2.0e-4
CODEX_STAGE2_WARMUP_EPOCHS = 0
CODEX_STAGE2_RAMP_EPOCHS = 10
CODEX_STAGE2_FREEZE_EPOCHS = 4

# FMPE SOTA configuration.
FMPE_MAX_EPOCHS = 50
FMPE_MAX_STEPS = None
FMPE_MAX_RUNTIME_SECONDS = FAIR_RUNTIME_BUDGET_SECONDS
FMPE_PATIENCE = 50
FMPE_BATCH_SIZE = 64
FMPE_EVAL_BATCH_SIZE = 128
FMPE_POSTERIOR_SAMPLES = 32
FMPE_PERIODIC_SAMPLES = 16
FMPE_CONTEXT_BATCH_SIZE = 16

DEVICE = torch.device("cpu")

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

cpu_threads = max(1, min(os.cpu_count() or 1, 8))
torch.set_num_threads(cpu_threads)
try:
    torch.set_num_interop_threads(max(1, min(cpu_threads // 2, 4)))
except RuntimeError:
    pass

config = {
    "project_root": str(PROJECT_ROOT),
    "data_root": str(DATA_ROOT),
    "output_root": str(OUTPUT_ROOT),
    "platform": platform.platform(),
    "seed": SEED,
    "train_rows": TRAIN_ROWS,
    "validation_rows": VALIDATION_ROWS,
    "holdout_rows": HOLDOUT_ROWS,
    "codex_qubits": CODEX_QNN_QUBITS,
    "codex_depth": CODEX_QNN_DEPTH,
    "fair_runtime_budget_seconds": FAIR_RUNTIME_BUDGET_SECONDS,
    "codex_stage1_budget_seconds": CODEX_STAGE1_BUDGET_SECONDS,
    "codex_stage1_epochs": CODEX_STAGE1_MAX_EPOCHS,
    "codex_stage2_epochs": CODEX_STAGE2_MAX_EPOCHS,
    "fmpe_epochs": FMPE_MAX_EPOCHS,
    "fmpe_max_runtime_seconds": FMPE_MAX_RUNTIME_SECONDS,
    "fmpe_max_steps": FMPE_MAX_STEPS,
}
config
# Out:
# {'project_root': '/Users/jkw/Documents/uni/axion/hack4sages/ariel/models/notebooks',
#  'data_root': '/Users/jkw/Documents/uni/axion/hack4sages/ariel',
#  'output_root': '/Users/jkw/Documents/uni/axion/hack4sages/ariel/models/notebooks/outputs/fair_small_compare/20260312_000541',
#  'platform': 'macOS-26.2-arm64-arm-64bit',
#  'seed': 42,
#  'train_rows': 256,
#  'validation_rows': 64,
#  'holdout_rows': 64,
#  'codex_qubits': 12,
#  'codex_depth': 2,
#  'fair_runtime_budget_seconds': 20.0,
#  'codex_stage1_budget_seconds': 4.0,
#  'codex_stage1_epochs': 50,
#  'codex_stage2_epochs': 50,
#  'fmpe_epochs': 50,
#  'fmpe_max_runtime_seconds': 20.0,
#  'fmpe_max_steps': None}

# %%
required_modules = {
    "numpy": "numpy",
    "pandas": "pandas",
    "h5py": "h5py",
    "PyYAML": "yaml",
    "PyTorch": "torch",
    "scikit-learn": "sklearn",
    "PennyLane": "pennylane",
    "Dingo": "dingo",
}
missing = [label for label, module_name in required_modules.items() if importlib.util.find_spec(module_name) is None]
if missing:
    print("Missing Python modules:", ", ".join(missing))
    print()
    print("Suggested local bootstrap commands from", PROJECT_ROOT)
    print("python -m pip install --upgrade pip")
    print("python -m pip install torch")
    print("python -m pip install --no-deps dingo-gw==0.8.3")
    print(f"python -m pip install -r {PROJECT_ROOT / 'models' / 'sbi_ariel_crossgen' / 'requirements-mac.txt'}")
    print("python -m pip install pennylane pennylane-lightning")
    raise RuntimeError("Install the missing dependencies, then rerun this cell.")

import h5py
import pandas as pd
import pennylane as qml
import yaml
from IPython.display import display
from sklearn.model_selection import train_test_split

from models.sbi_ariel_adc2023.constants import (
    AUX_FEATURE_COLS as FMPE_AUX_FEATURE_COLS,
    CONTEXT_DIM,
    CONTEXT_FILENAME_TEMPLATE,
    DATASET_TYPE,
    HOLDOUT_SPLIT,
    LOG10_AUX_FEATURE_COLS as FMPE_LOG10_AUX_FEATURE_COLS,
    MANIFEST_FILENAME,
    METADATA_FILENAME_TEMPLATE,
    NORMALIZATION_FILENAME,
    NORMALIZATION_MODE,
    RAW_TARGET_FILENAME_TEMPLATE,
    TARGET_COLS,
    TARGET_FILENAME_TEMPLATE,
    TESTDATA_SPLIT,
    THETA_DIM,
    TRAIN_SPLIT,
    VALIDATION_SPLIT,
    WAVELENGTH_FILENAME,
)
from models.sbi_ariel_adc2023.dataset import load_datasets
from models.sbi_ariel_adc2023.evaluate import run_regression_evaluation
from models.ariel_quantum_regression.constants import (
    AUX_COLUMNS as CODEX_AUX_COLUMNS,
    FIXED_SPECTRAL_CHANNELS,
    HDF5_GROUP_PREFIX,
    LOG10_AUX_COLUMNS as CODEX_LOG10_AUX_COLUMNS,
    MODEL_SPECTRAL_CHANNELS,
    PRESENCE_THRESHOLD_LOG10_VMR,
    RAW_SPECTRAL_CHANNELS,
    SAMPLE_SPECTRAL_CHANNELS,
    TARGET_COLUMNS as CODEX_TARGET_COLUMNS,
    WAVELENGTH_DATASET,
)
from models.ariel_quantum_regression.dataset import (
    ArrayStandardizer,
    PreparedData,
    SpectralStandardizer,
    _expected_manifest,
    _make_inference_split,
    _make_labeled_split,
    _normalize_fixed_channel,
    _normalize_sample_spectra,
    _save_prepared_cache,
    build_stratify_labels,
    transform_aux_features,
)

import importlib
import models.sbi_ariel_adc2023.training as fmpe_training_module
import models.ariel_quantum_regression.training as codex_training_module

fmpe_training_module = importlib.reload(fmpe_training_module)
codex_training_module = importlib.reload(codex_training_module)

train_model = fmpe_training_module.train_model
TrainingConfig = codex_training_module.TrainingConfig
run_training_experiment = codex_training_module.run_training_experiment

QUANTUM_DEVICE = "lightning.qubit" if importlib.util.find_spec("pennylane_lightning") is not None else "default.qubit"

print(f"PyTorch: {torch.__version__}")
print(f"PennyLane: {qml.__version__}")
print(f"Device: {DEVICE} | Quantum backend: {QUANTUM_DEVICE}")
# Out:
# PyTorch: 2.10.0
# PennyLane: 0.44.1
# Device: cpu | Quantum backend: lightning.qubit

# %%
def _drop_unnamed_columns(frame: pd.DataFrame) -> pd.DataFrame:
    unnamed = [column for column in frame.columns if column.startswith("Unnamed:")]
    if unnamed:
        frame = frame.drop(columns=unnamed)
    return frame


def _load_spectra(hdf5_path: Path, planet_ids: np.ndarray) -> tuple[np.ndarray, np.ndarray]:
    spectra = np.empty((len(planet_ids), 52, len(RAW_SPECTRAL_CHANNELS)), dtype=np.float32)
    wavelength_um = None
    with h5py.File(hdf5_path, "r") as handle:
        for row_index, planet_id in enumerate(planet_ids.tolist()):
            group = handle[f"{HDF5_GROUP_PREFIX}{planet_id}"]
            row_wavelength = np.asarray(group[WAVELENGTH_DATASET][:], dtype=np.float32)
            if wavelength_um is None:
                wavelength_um = row_wavelength
            elif not np.allclose(row_wavelength, wavelength_um, atol=1.0e-8):
                raise AssertionError(f"Wavelength mismatch for {planet_id}")
            for channel_index, channel_name in enumerate(RAW_SPECTRAL_CHANNELS):
                spectra[row_index, :, channel_index] = np.asarray(group[channel_name][:], dtype=np.float32)
    if wavelength_um is None:
        raise RuntimeError(f"No spectra found in {hdf5_path}")
    return spectra, wavelength_um


train_aux_df = _drop_unnamed_columns(pd.read_csv(DATA_ROOT / "TrainingData" / "AuxillaryTable.csv"))
train_targets_df = _drop_unnamed_columns(
    pd.read_csv(DATA_ROOT / "TrainingData" / "Ground Truth Package" / "FM_Parameter_Table.csv")
)
labels = train_aux_df.merge(train_targets_df[["planet_ID", *TARGET_COLS]], on="planet_ID", how="inner", validate="one_to_one")
labels = labels.reset_index(drop=True)

train_spectra_raw, wavelength_um = _load_spectra(
    DATA_ROOT / "TrainingData" / "SpectralData.hdf5",
    labels["planet_ID"].to_numpy(dtype="U32"),
)
test_aux_df = _drop_unnamed_columns(pd.read_csv(DATA_ROOT / "TestData" / "AuxillaryTable.csv"))
test_spectra_raw, test_wavelength_um = _load_spectra(
    DATA_ROOT / "TestData" / "SpectralData.hdf5",
    test_aux_df["planet_ID"].to_numpy(dtype="U32"),
)
if not np.allclose(wavelength_um, test_wavelength_um, atol=1.0e-8):
    raise AssertionError("Training and test wavelength grids do not match.")

targets_raw = labels[TARGET_COLS].to_numpy(dtype=np.float32, copy=True)
print(f"Training rows: {len(labels):,}")
print(f"Challenge test rows: {len(test_aux_df):,}")
print(f"Wavelength bins: {len(wavelength_um)}")
# Out:
# Training rows: 41,423
# Challenge test rows: 685
# Wavelength bins: 52

# %%
all_indices = np.arange(len(labels), dtype=np.int64)
stratify_all, stratify_mode_all = build_stratify_labels(targets_raw)
train_pool, temp_pool = train_test_split(
    all_indices,
    test_size=0.2,
    random_state=SEED,
    shuffle=True,
    stratify=stratify_all if stratify_all is not None else None,
)
temp_targets_raw = targets_raw[temp_pool]
stratify_temp, stratify_mode_temp = build_stratify_labels(temp_targets_raw)
temp_positions = np.arange(len(temp_pool), dtype=np.int64)
validation_positions, holdout_positions = train_test_split(
    temp_positions,
    test_size=0.5,
    random_state=SEED + 1,
    shuffle=True,
    stratify=stratify_temp if stratify_temp is not None else None,
)

validation_pool = temp_pool[validation_positions]
holdout_pool = temp_pool[holdout_positions]
rng = np.random.default_rng(SEED)


def take_subset(indices: np.ndarray, limit: int) -> np.ndarray:
    if limit >= len(indices):
        return np.sort(indices.astype(np.int64))
    chosen = rng.choice(indices, size=int(limit), replace=False)
    return np.sort(chosen.astype(np.int64))


train_idx = take_subset(train_pool, TRAIN_ROWS)
validation_idx = take_subset(validation_pool, VALIDATION_ROWS)
holdout_idx = take_subset(holdout_pool, HOLDOUT_ROWS)

split_frame = pd.DataFrame(
    {
        "split": ([TRAIN_SPLIT] * len(train_idx)) + ([VALIDATION_SPLIT] * len(validation_idx)) + ([HOLDOUT_SPLIT] * len(holdout_idx)),
        "planet_ID": np.concatenate(
            [
                labels.iloc[train_idx]["planet_ID"].to_numpy(dtype="U32"),
                labels.iloc[validation_idx]["planet_ID"].to_numpy(dtype="U32"),
                labels.iloc[holdout_idx]["planet_ID"].to_numpy(dtype="U32"),
            ]
        ),
        "source_row_index": np.concatenate([train_idx, validation_idx, holdout_idx]),
    }
)
SHARED_SPLIT_PATH = OUTPUT_ROOT / "shared_split.csv"
split_frame.to_csv(SHARED_SPLIT_PATH, index=False)

shared_split_manifest = {
    "seed": SEED,
    "stratify_mode_train_split": stratify_mode_all,
    "stratify_mode_validation_split": stratify_mode_temp,
    "train_rows": int(len(train_idx)),
    "validation_rows": int(len(validation_idx)),
    "holdout_rows": int(len(holdout_idx)),
    "shared_split_file": str(SHARED_SPLIT_PATH),
}
(OUTPUT_ROOT / "shared_split_manifest.json").write_text(json.dumps(shared_split_manifest, indent=2, sort_keys=True) + "\n")
split_frame.groupby("split").size().to_frame("rows")
# Out:
#             rows
# split
# holdout       64
# train        256
# validation    64

# %%
def safe_scale(values: np.ndarray) -> np.ndarray:
    scale = values.std(axis=0, ddof=0).astype(np.float32)
    return np.where(scale == 0.0, 1.0, scale).astype(np.float32)


def normalize_spectrum(values: np.ndarray) -> np.ndarray:
    sample_mean = values.mean(axis=1, keepdims=True)
    sample_mean = np.clip(sample_mean, 1.0e-12, None)
    return (values / sample_mean).astype(np.float32)


def log_noise(values: np.ndarray) -> np.ndarray:
    return np.log10(np.clip(values.astype(np.float32), 1.0e-12, None)).astype(np.float32)


def compute_zscore(values: np.ndarray) -> tuple[np.ndarray, np.ndarray]:
    mean = values.mean(axis=0).astype(np.float32)
    scale = safe_scale(values)
    return mean, scale


def apply_zscore(values: np.ndarray, mean: np.ndarray, scale: np.ndarray) -> np.ndarray:
    return ((values - mean) / scale).astype(np.float32)


def metadata_frame(indices: np.ndarray) -> pd.DataFrame:
    return pd.DataFrame(
        {
            "planet_ID": labels.iloc[indices]["planet_ID"].to_numpy(dtype="U32"),
            "source_row_index": indices.astype(np.int64),
        }
    )


CODEX_PREPARED_CACHE_DIR = OUTPUT_ROOT / "codex_prepared_cache"
if CODEX_PREPARED_CACHE_DIR.exists():
    shutil.rmtree(CODEX_PREPARED_CACHE_DIR)
CODEX_PREPARED_CACHE_DIR.mkdir(parents=True, exist_ok=True)

codex_aux_raw = transform_aux_features(labels)
codex_test_aux_raw = transform_aux_features(test_aux_df)
codex_targets_raw = labels[CODEX_TARGET_COLUMNS].to_numpy(dtype=np.float32, copy=True)
sample_channel_indices = [RAW_SPECTRAL_CHANNELS.index(name) for name in SAMPLE_SPECTRAL_CHANNELS]
width_channel_index = RAW_SPECTRAL_CHANNELS.index("instrument_width")
codex_train_sample_spectra = np.transpose(train_spectra_raw[:, :, sample_channel_indices], (0, 2, 1)).astype(np.float32)
codex_test_sample_spectra = np.transpose(test_spectra_raw[:, :, sample_channel_indices], (0, 2, 1)).astype(np.float32)
codex_train_sample_spectra = _normalize_sample_spectra(codex_train_sample_spectra)
codex_test_sample_spectra = _normalize_sample_spectra(codex_test_sample_spectra)
fixed_channels = np.stack(
    [
        _normalize_fixed_channel(train_spectra_raw[0, :, width_channel_index]),
        _normalize_fixed_channel(wavelength_um),
    ],
    axis=0,
).astype(np.float32)
codex_aux_scaler = ArrayStandardizer.fit(codex_aux_raw[train_idx])
codex_target_scaler = ArrayStandardizer.fit(codex_targets_raw[train_idx])
codex_spectral_scaler = SpectralStandardizer.fit(codex_train_sample_spectra[train_idx], fixed_channels=fixed_channels)


def make_codex_labeled_split(indices: np.ndarray):
    aux_scaled = codex_aux_scaler.transform(codex_aux_raw[indices])
    spectra_scaled = codex_spectral_scaler.transform(codex_train_sample_spectra[indices])
    raw_targets = codex_targets_raw[indices]
    targets_scaled = codex_target_scaler.transform(raw_targets)
    return _make_labeled_split(
        planet_ids=labels.iloc[indices]["planet_ID"].to_numpy(dtype="U32"),
        aux_values=aux_scaled,
        spectra_values=spectra_scaled,
        targets_scaled=targets_scaled,
        raw_targets=raw_targets,
    )


codex_test_split = _make_inference_split(
    planet_ids=test_aux_df["planet_ID"].to_numpy(dtype="U32"),
    aux_values=codex_aux_scaler.transform(codex_test_aux_raw),
    spectra_values=codex_spectral_scaler.transform(codex_test_sample_spectra),
)
codex_split_manifest = {
    "rows_total": int(len(labels)),
    "testdata_rows_total": int(len(test_aux_df)),
    "train_rows": int(len(train_idx)),
    "val_rows": int(len(validation_idx)),
    "holdout_rows": int(len(holdout_idx)),
    "testdata_rows": int(len(test_aux_df)),
    "wavelength_bins": int(len(wavelength_um)),
    "wavelength_min_um": float(wavelength_um.min()),
    "wavelength_max_um": float(wavelength_um.max()),
    "raw_spectrum_shape": [52, len(RAW_SPECTRAL_CHANNELS)],
    "model_spectrum_shape": [len(MODEL_SPECTRAL_CHANNELS), 52],
    "aux_columns": CODEX_AUX_COLUMNS,
    "log10_aux_columns": CODEX_LOG10_AUX_COLUMNS,
    "target_columns": CODEX_TARGET_COLUMNS,
    "raw_spectral_channels": RAW_SPECTRAL_CHANNELS,
    "sample_spectral_channels": SAMPLE_SPECTRAL_CHANNELS,
    "fixed_spectral_channels": FIXED_SPECTRAL_CHANNELS,
    "model_spectral_channels": MODEL_SPECTRAL_CHANNELS,
    "sample_spectral_normalization": {
        "mode": "divide_by_sample_mean",
        "reference_channel": SAMPLE_SPECTRAL_CHANNELS[0],
        "applied_channels": SAMPLE_SPECTRAL_CHANNELS,
    },
    "presence_threshold_log10_vmr": PRESENCE_THRESHOLD_LOG10_VMR,
    "split_seed": int(SEED),
    "split_fractions": {"train": 0.8, "val": 0.1, "holdout": 0.1},
    "primary_stratify_mode": stratify_mode_all,
    "secondary_stratify_mode": stratify_mode_temp,
    "shared_split_file": str(SHARED_SPLIT_PATH),
}
codex_expected_manifest = _expected_manifest(
    DATA_ROOT,
    SEED,
    int(len(train_idx)),
    int(len(validation_idx)),
    int(len(holdout_idx)),
    None,
)
codex_prepared_manifest = dict(codex_expected_manifest)
codex_prepared_manifest["cache_dir"] = str(CODEX_PREPARED_CACHE_DIR)
codex_prepared_manifest["cache_hit"] = False
codex_prepared = PreparedData(
    train=make_codex_labeled_split(train_idx),
    val=make_codex_labeled_split(validation_idx),
    holdout=make_codex_labeled_split(holdout_idx),
    testdata=codex_test_split,
    aux_scaler=codex_aux_scaler,
    target_scaler=codex_target_scaler,
    spectral_scaler=codex_spectral_scaler,
    wavelength_um=wavelength_um.astype(np.float32),
    split_manifest=codex_split_manifest,
    prepared_manifest=codex_prepared_manifest,
)
_save_prepared_cache(CODEX_PREPARED_CACHE_DIR, codex_expected_manifest, codex_prepared)

FMPE_PREPARED_DIR = OUTPUT_ROOT / "fmpe_prepared_dataset"
if FMPE_PREPARED_DIR.exists():
    shutil.rmtree(FMPE_PREPARED_DIR)
FMPE_PREPARED_DIR.mkdir(parents=True, exist_ok=True)
fmpe_labeled_spectrum = normalize_spectrum(train_spectra_raw[:, :, RAW_SPECTRAL_CHANNELS.index("instrument_spectrum")])
fmpe_test_spectrum = normalize_spectrum(test_spectra_raw[:, :, RAW_SPECTRAL_CHANNELS.index("instrument_spectrum")])
fmpe_labeled_noise = log_noise(train_spectra_raw[:, :, RAW_SPECTRAL_CHANNELS.index("instrument_noise")])
fmpe_test_noise = log_noise(test_spectra_raw[:, :, RAW_SPECTRAL_CHANNELS.index("instrument_noise")])
fmpe_labeled_aux = labels[FMPE_AUX_FEATURE_COLS].to_numpy(dtype=np.float32, copy=True)
fmpe_test_aux = test_aux_df[FMPE_AUX_FEATURE_COLS].to_numpy(dtype=np.float32, copy=True)
for col_index, col_name in enumerate(FMPE_AUX_FEATURE_COLS):
    if col_name in FMPE_LOG10_AUX_FEATURE_COLS:
        fmpe_labeled_aux[:, col_index] = np.log10(np.clip(fmpe_labeled_aux[:, col_index], 1.0e-12, None))
        fmpe_test_aux[:, col_index] = np.log10(np.clip(fmpe_test_aux[:, col_index], 1.0e-12, None))
fmpe_targets_raw = labels[TARGET_COLS].to_numpy(dtype=np.float32, copy=True)
spectrum_mean, spectrum_scale = compute_zscore(fmpe_labeled_spectrum[train_idx])
noise_mean, noise_scale = compute_zscore(fmpe_labeled_noise[train_idx])
aux_mean, aux_scale = compute_zscore(fmpe_labeled_aux[train_idx])
target_mean, target_scale = compute_zscore(fmpe_targets_raw[train_idx])


def fmpe_context(indices: np.ndarray) -> np.ndarray:
    return np.concatenate(
        [
            apply_zscore(fmpe_labeled_spectrum[indices], spectrum_mean, spectrum_scale),
            apply_zscore(fmpe_labeled_noise[indices], noise_mean, noise_scale),
            apply_zscore(fmpe_labeled_aux[indices], aux_mean, aux_scale),
        ],
        axis=1,
    ).astype(np.float32)


def write_fmpe_labeled_split(split_name: str, indices: np.ndarray) -> None:
    np.save(FMPE_PREPARED_DIR / CONTEXT_FILENAME_TEMPLATE.format(split_name=split_name), fmpe_context(indices))
    np.save(
        FMPE_PREPARED_DIR / TARGET_FILENAME_TEMPLATE.format(split_name=split_name),
        apply_zscore(fmpe_targets_raw[indices], target_mean, target_scale),
    )
    np.save(
        FMPE_PREPARED_DIR / RAW_TARGET_FILENAME_TEMPLATE.format(split_name=split_name),
        fmpe_targets_raw[indices].astype(np.float32),
    )
    metadata_frame(indices).to_csv(
        FMPE_PREPARED_DIR / METADATA_FILENAME_TEMPLATE.format(split_name=split_name),
        index=False,
    )


write_fmpe_labeled_split(TRAIN_SPLIT, train_idx)
write_fmpe_labeled_split(VALIDATION_SPLIT, validation_idx)
write_fmpe_labeled_split(HOLDOUT_SPLIT, holdout_idx)
test_context = np.concatenate(
    [
        apply_zscore(fmpe_test_spectrum, spectrum_mean, spectrum_scale),
        apply_zscore(fmpe_test_noise, noise_mean, noise_scale),
        apply_zscore(fmpe_test_aux, aux_mean, aux_scale),
    ],
    axis=1,
).astype(np.float32)
np.save(FMPE_PREPARED_DIR / CONTEXT_FILENAME_TEMPLATE.format(split_name=TESTDATA_SPLIT), test_context)
pd.DataFrame(
    {
        "planet_ID": test_aux_df["planet_ID"].to_numpy(dtype="U32"),
        "source_row_index": np.arange(len(test_aux_df), dtype=np.int64),
    }
).to_csv(FMPE_PREPARED_DIR / METADATA_FILENAME_TEMPLATE.format(split_name=TESTDATA_SPLIT), index=False)
np.savez(
    FMPE_PREPARED_DIR / NORMALIZATION_FILENAME,
    spectrum_mean=spectrum_mean,
    spectrum_scale=spectrum_scale,
    noise_mean=noise_mean,
    noise_scale=noise_scale,
    aux_mean=aux_mean,
    aux_scale=aux_scale,
    target_mean=target_mean,
    target_scale=target_scale,
)
np.save(FMPE_PREPARED_DIR / WAVELENGTH_FILENAME, wavelength_um.astype(np.float32))
fmpe_manifest = {
    "data_root": str(DATA_ROOT),
    "prepared_dir": str(FMPE_PREPARED_DIR),
    "dataset_type": DATASET_TYPE,
    "normalization_mode": NORMALIZATION_MODE,
    "seed": SEED,
    "split_fractions": {"train": None, "validation": None, "holdout": None},
    "split_counts": {
        TRAIN_SPLIT: int(len(train_idx)),
        VALIDATION_SPLIT: int(len(validation_idx)),
        HOLDOUT_SPLIT: int(len(holdout_idx)),
        TESTDATA_SPLIT: int(len(test_aux_df)),
    },
    "context_dim": CONTEXT_DIM,
    "theta_dim": THETA_DIM,
    "target_columns": TARGET_COLS,
    "aux_feature_cols": FMPE_AUX_FEATURE_COLS,
    "log10_aux_feature_cols": FMPE_LOG10_AUX_FEATURE_COLS,
    "wavelength_bins": int(len(wavelength_um)),
    "wavelength_min_um": float(wavelength_um.min()),
    "wavelength_max_um": float(wavelength_um.max()),
    "feature_order": [
        "normalized_instrument_spectrum[52]",
        "log10_instrument_noise[52]",
        *FMPE_AUX_FEATURE_COLS,
    ],
    "shared_split_file": str(SHARED_SPLIT_PATH),
}
(FMPE_PREPARED_DIR / MANIFEST_FILENAME).write_text(json.dumps(fmpe_manifest, indent=2, sort_keys=True) + "\n")

print(f"Codex prepared cache: {CODEX_PREPARED_CACHE_DIR}")
print(f"FMPE prepared dataset: {FMPE_PREPARED_DIR}")
# Out:
# Codex prepared cache: /Users/jkw/Documents/uni/axion/hack4sages/ariel/models/notebooks/outputs/fair_small_compare/20260312_000541/codex_prepared_cache
# FMPE prepared dataset: /Users/jkw/Documents/uni/axion/hack4sages/ariel/models/notebooks/outputs/fair_small_compare/20260312_000541/fmpe_prepared_dataset

# %%
CODEX_OUTPUT_ROOT = OUTPUT_ROOT / "codex"
if CODEX_OUTPUT_ROOT.exists():
    shutil.rmtree(CODEX_OUTPUT_ROOT)
CODEX_OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)
CODEX_STAGE1_OUTPUT_DIR = CODEX_OUTPUT_ROOT / "stage1_classical"
CODEX_STAGE2_OUTPUT_DIR = CODEX_OUTPUT_ROOT / "stage2_hybrid"


def make_codex_stage1_config(output_dir: Path, runtime_seconds: float) -> TrainingConfig:
    return TrainingConfig(
        project_root=str(PROJECT_ROOT),
        data_root=str(DATA_ROOT),
        output_dir=str(output_dir),
        prepared_cache_dir=str(CODEX_PREPARED_CACHE_DIR),
        seed=SEED,
        batch_size=CODEX_STAGE1_BATCH_SIZE,
        eval_batch_size=CODEX_STAGE1_EVAL_BATCH_SIZE,
        max_epochs=CODEX_STAGE1_MAX_EPOCHS,
        max_runtime_seconds=runtime_seconds,
        early_stop_patience=CODEX_STAGE1_EARLY_STOP,
        scheduler_patience=CODEX_STAGE1_SCHEDULER_PATIENCE,
        scheduler_factor=0.5,
        classical_lr=CODEX_STAGE1_CLASSICAL_LR,
        weight_decay=CODEX_WEIGHT_DECAY,
        gradient_clip_norm=CODEX_GRADIENT_CLIP,
        dropout=CODEX_DROPOUT,
        loss_name="mse",
        qnn_qubits=CODEX_QNN_QUBITS,
        qnn_depth=CODEX_QNN_DEPTH,
        qnn_init_scale=CODEX_QNN_INIT_SCALE,
        quantum_device=QUANTUM_DEVICE,
        quantum_use_async=False,
        classical_only=True,
        use_amp=False,
        log_every_batches=10,
        train_limit=len(train_idx),
        val_limit=len(validation_idx),
        holdout_limit=len(holdout_idx),
    )


def make_codex_stage2_config(output_dir: Path, checkpoint_path: Path, runtime_seconds: float) -> TrainingConfig:
    return TrainingConfig(
        project_root=str(PROJECT_ROOT),
        data_root=str(DATA_ROOT),
        output_dir=str(output_dir),
        prepared_cache_dir=str(CODEX_PREPARED_CACHE_DIR),
        init_checkpoint_path=str(checkpoint_path),
        seed=SEED,
        batch_size=CODEX_STAGE2_BATCH_SIZE,
        eval_batch_size=CODEX_STAGE2_EVAL_BATCH_SIZE,
        max_epochs=CODEX_STAGE2_MAX_EPOCHS,
        max_runtime_seconds=runtime_seconds,
        early_stop_patience=CODEX_STAGE2_EARLY_STOP,
        scheduler_patience=CODEX_STAGE2_SCHEDULER_PATIENCE,
        scheduler_factor=0.5,
        classical_lr=CODEX_STAGE2_CLASSICAL_LR,
        quantum_lr=CODEX_STAGE2_QUANTUM_LR,
        weight_decay=CODEX_WEIGHT_DECAY,
        gradient_clip_norm=CODEX_GRADIENT_CLIP,
        dropout=CODEX_DROPOUT,
        loss_name="mse",
        qnn_qubits=CODEX_QNN_QUBITS,
        qnn_depth=CODEX_QNN_DEPTH,
        qnn_init_scale=CODEX_QNN_INIT_SCALE,
        quantum_device=QUANTUM_DEVICE,
        quantum_use_async=False,
        quantum_warmup_epochs=CODEX_STAGE2_WARMUP_EPOCHS,
        quantum_ramp_epochs=CODEX_STAGE2_RAMP_EPOCHS,
        quantum_backbone_freeze_epochs=CODEX_STAGE2_FREEZE_EPOCHS,
        classical_only=False,
        use_amp=False,
        log_every_batches=10,
        train_limit=len(train_idx),
        val_limit=len(validation_idx),
        holdout_limit=len(holdout_idx),
    )


codex_training_start = time.perf_counter()
codex_stage1_cfg = make_codex_stage1_config(CODEX_STAGE1_OUTPUT_DIR, CODEX_STAGE1_BUDGET_SECONDS)
print(json.dumps(codex_stage1_cfg.to_json_dict(), indent=2))
codex_stage1_result = run_training_experiment(codex_stage1_cfg)
print(json.dumps(codex_stage1_result["summary"], indent=2))

codex_stage1_checkpoint = (CODEX_STAGE1_OUTPUT_DIR / "best_model.pt").resolve()
if not codex_stage1_checkpoint.exists():
    raise FileNotFoundError(f"Missing Codex stage-1 checkpoint: {codex_stage1_checkpoint}")

codex_stage2_budget_seconds = max(1.0, FAIR_RUNTIME_BUDGET_SECONDS - (time.perf_counter() - codex_training_start))
codex_stage2_cfg = make_codex_stage2_config(CODEX_STAGE2_OUTPUT_DIR, codex_stage1_checkpoint, codex_stage2_budget_seconds)
print(json.dumps(codex_stage2_cfg.to_json_dict(), indent=2))
codex_stage2_result = run_training_experiment(codex_stage2_cfg)
print(json.dumps(codex_stage2_result["summary"], indent=2))

codex_result = {
    "model": "codex_two_stage_12q",
    "best_epoch": int(codex_stage2_result["summary"]["best_epoch"]),
    "best_val_rmse_mean": float(codex_stage2_result["summary"]["best_val_rmse_mean"]),
    "validation_rmse_mean": float(codex_stage2_result["summary"]["validation_rmse_mean"]),
    "holdout_rmse_mean": float(codex_stage2_result["summary"]["holdout_rmse_mean"]),
    "validation_rmse": {
        name: float(value)
        for name, value in zip(CODEX_TARGET_COLUMNS, codex_stage2_result["validation_metrics"]["rmse_orig"])
    },
    "holdout_rmse": {
        name: float(value)
        for name, value in zip(CODEX_TARGET_COLUMNS, codex_stage2_result["holdout_metrics"]["rmse_orig"])
    },
    "hyperparameters": {
        "qnn_qubits": CODEX_QNN_QUBITS,
        "qnn_depth": CODEX_QNN_DEPTH,
        "total_runtime_budget_seconds": FAIR_RUNTIME_BUDGET_SECONDS,
        "stage1_runtime_budget_seconds": CODEX_STAGE1_BUDGET_SECONDS,
        "stage2_runtime_budget_seconds": codex_stage2_budget_seconds,
        "stage1_batch_size": CODEX_STAGE1_BATCH_SIZE,
        "stage1_epochs": CODEX_STAGE1_MAX_EPOCHS,
        "stage1_classical_lr": CODEX_STAGE1_CLASSICAL_LR,
        "stage2_batch_size": CODEX_STAGE2_BATCH_SIZE,
        "stage2_epochs": CODEX_STAGE2_MAX_EPOCHS,
        "stage2_classical_lr": CODEX_STAGE2_CLASSICAL_LR,
        "stage2_quantum_lr": CODEX_STAGE2_QUANTUM_LR,
        "stage2_quantum_ramp_epochs": CODEX_STAGE2_RAMP_EPOCHS,
        "stage2_quantum_backbone_freeze_epochs": CODEX_STAGE2_FREEZE_EPOCHS,
    },
    "stage1_summary": codex_stage1_result["summary"],
    "stage2_summary": codex_stage2_result["summary"],
}
(CODEX_OUTPUT_ROOT / "summary.json").write_text(json.dumps(codex_result, indent=2, sort_keys=True) + "\n")
codex_result
# Out:
# {
#   "project_root": "/Users/jkw/Documents/uni/axion/hack4sages/ariel/models/notebooks",
#   "data_root": "/Users/jkw/Documents/uni/axion/hack4sages/ariel",
#   "output_dir": "/Users/jkw/Documents/uni/axion/hack4sages/ariel/models/notebooks/outputs/fair_small_compare/20260312_000541/codex/stage1_classical",
#   "prepared_cache_dir": "/Users/jkw/Documents/uni/axion/hack4sages/ariel/models/notebooks/outputs/fair_small_compare/20260312_000541/codex_prepared_cache",
#   "init_checkpoint_path": null,
#   "seed": 42,
#   "batch_size": 64,
#   "eval_batch_size": 128,
#   "max_epochs": 50,
#   "max_runtime_seconds": 4.0,
#   "early_stop_patience": 50,
#   "scheduler_patience": 6,
#   "scheduler_factor": 0.5,
#   "classical_lr": 0.001,
#   "quantum_lr": 0.0008,
#   "weight_decay": 0.0001,
#   "gradient_clip_norm": 5.0,
#   "dropout": 0.05,
#   "loss_name": "mse",
#   "qnn_qubits": 12,
#   "qnn_depth": 2,
#   "qnn_init_scale": 0.1,
#   "quantum_device": "lightning.qubit",
#   "quantum_use_async": false,
#   "classical_only": true,
#   "quantum_warmup_epochs": 5,
#   "quantum_ramp_epochs": 4,
#   "quantum_backbone_freeze_epochs": 0,
#   "use_amp": false,
#   "log_every_batches": 10,
#   "train_limit": 256,
#   "val_limit": 64,
#   "holdout_limit": 64,
#   "test_limit": null,
#   "aux_columns": [
#     "star_distance",
#     "star_mass_kg",
#     "star_radius_m",
#     "star_temperature",
#     "planet_mass_kg",
#     "planet_orbital_period",
#     "planet_distance",
#     "planet_surface_gravity"
#   ],
#   "target_columns": [
#     "log_H2O",
#     "log_CO2",
#     "log_CO",
#     "log_CH4",
#     "log_NH3"
#   ]
# }
# Project root: /Users/jkw/Documents/uni/axion/hack4sages/ariel/models/notebooks
# Data root: /Users/jkw/Documents/uni/axion/hack4sages/ariel
# Output dir: /Users/jkw/Documents/uni/axion/hack4sages/ariel/models/notebooks/outputs/fair_small_compare/20260312_000541/codex/stage1_classical
# Batch size: 64
# Eval batch size: 128
# Quantum width/depth: 12/2
# Quantum async: False
# Loss: mse
# Quantum warmup epochs: 0
# Quantum ramp epochs: 0
# Quantum backbone freeze epochs: 0
# Prepared cache dir: /Users/jkw/Documents/uni/axion/hack4sages/ariel/models/notebooks/outputs/fair_small_compare/20260312_000541/codex_prepared_cache
# Torch device: mps | Quantum device: lightning.qubit | classical_only=True
# Loss: mse | Quantum warmup epochs: 0 | Quantum ramp epochs: 0 | Backbone freeze epochs: 0
# Max runtime seconds: 4.0
# Epoch 1/50 | Batch 4/4 | batch_loss=0.95887 | avg_loss=1.01355 | batch_time=0.02s
# Epoch 1/50 | train_loss=1.01355 | train_rmse_mean=1.47310 | val_rmse_mean=1.39898 | val_mae_mean=1.19072 | time=0.1s | lr=(1.00e-03, 8.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=1.8116 | log_CO2=1.4316 | log_CO=0.8877 | log_CH4=1.7306 | log_NH3=1.5040
# Validation RMSE | log_H2O=1.6426 | log_CO2=1.3430 | log_CO=0.9265 | log_CH4=1.6723 | log_NH3=1.4104
# Validation MAE  | log_H2O=1.4006 | log_CO2=1.1329 | log_CO=0.8027 | log_CH4=1.4280 | log_NH3=1.1893
# Epoch 2/50 | Batch 4/4 | batch_loss=1.01643 | avg_loss=0.99576 | batch_time=0.02s
# Epoch 2/50 | train_loss=0.99576 | train_rmse_mean=1.45980 | val_rmse_mean=1.39569 | val_mae_mean=1.18235 | time=0.1s | lr=(1.00e-03, 8.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=1.7965 | log_CO2=1.4431 | log_CO=0.8758 | log_CH4=1.6890 | log_NH3=1.4946
# Validation RMSE | log_H2O=1.6651 | log_CO2=1.3718 | log_CO=0.9366 | log_CH4=1.5937 | log_NH3=1.4113
# Validation MAE  | log_H2O=1.4143 | log_CO2=1.1622 | log_CO=0.8061 | log_CH4=1.3482 | log_NH3=1.1810
# Epoch 3/50 | Batch 4/4 | batch_loss=0.97643 | avg_loss=0.95457 | batch_time=0.02s
# Epoch 3/50 | train_loss=0.95457 | train_rmse_mean=1.42215 | val_rmse_mean=1.33534 | val_mae_mean=1.11822 | time=0.1s | lr=(1.00e-03, 8.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=1.7920 | log_CO2=1.4388 | log_CO=0.8769 | log_CH4=1.5152 | log_NH3=1.4878
# Validation RMSE | log_H2O=1.6570 | log_CO2=1.4602 | log_CO=0.8930 | log_CH4=1.2596 | log_NH3=1.4070
# Validation MAE  | log_H2O=1.4070 | log_CO2=1.2419 | log_CO=0.7668 | log_CH4=0.9937 | log_NH3=1.1816
# Epoch 4/50 | Batch 4/4 | batch_loss=0.81355 | avg_loss=0.86883 | batch_time=0.02s
# Epoch 4/50 | train_loss=0.86883 | train_rmse_mean=1.32223 | val_rmse_mean=1.26509 | val_mae_mean=1.06650 | time=0.1s | lr=(1.00e-03, 8.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=1.7667 | log_CO2=1.4315 | log_CO=0.8906 | log_CH4=1.0461 | log_NH3=1.4763
# Validation RMSE | log_H2O=1.6930 | log_CO2=1.4306 | log_CO=0.9264 | log_CH4=0.8818 | log_NH3=1.3937
# Validation MAE  | log_H2O=1.4637 | log_CO2=1.2096 | log_CO=0.7991 | log_CH4=0.6930 | log_NH3=1.1671
# Epoch 5/50 | Batch 4/4 | batch_loss=0.89770 | avg_loss=0.86285 | batch_time=0.02s
# Epoch 5/50 | train_loss=0.86285 | train_rmse_mean=1.32588 | val_rmse_mean=1.23512 | val_mae_mean=1.04254 | time=0.1s | lr=(1.00e-03, 8.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=1.7157 | log_CO2=1.4242 | log_CO=0.8772 | log_CH4=1.1365 | log_NH3=1.4757
# Validation RMSE | log_H2O=1.6201 | log_CO2=1.3956 | log_CO=0.9309 | log_CH4=0.8618 | log_NH3=1.3672
# Validation MAE  | log_H2O=1.3977 | log_CO2=1.1820 | log_CO=0.8046 | log_CH4=0.6898 | log_NH3=1.1385
# Epoch 6/50 | Batch 4/4 | batch_loss=0.82214 | avg_loss=0.83241 | batch_time=0.02s
# Epoch 6/50 | train_loss=0.83241 | train_rmse_mean=1.28656 | val_rmse_mean=1.20444 | val_mae_mean=1.02155 | time=0.1s | lr=(1.00e-03, 8.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=1.6914 | log_CO2=1.4260 | log_CO=0.8843 | log_CH4=0.9809 | log_NH3=1.4502
# Validation RMSE | log_H2O=1.5364 | log_CO2=1.3642 | log_CO=0.9164 | log_CH4=0.8886 | log_NH3=1.3166
# Validation MAE  | log_H2O=1.3225 | log_CO2=1.1605 | log_CO=0.7954 | log_CH4=0.7223 | log_NH3=1.1070
# Epoch 7/50 | Batch 4/4 | batch_loss=0.71016 | avg_loss=0.78632 | batch_time=0.02s
# Epoch 7/50 | train_loss=0.78632 | train_rmse_mean=1.24024 | val_rmse_mean=1.17442 | val_mae_mean=0.98809 | time=0.1s | lr=(1.00e-03, 8.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=1.6232 | log_CO2=1.4031 | log_CO=0.8769 | log_CH4=0.8901 | log_NH3=1.4079
# Validation RMSE | log_H2O=1.4500 | log_CO2=1.3789 | log_CO=0.9300 | log_CH4=0.8424 | log_NH3=1.2708
# Validation MAE  | log_H2O=1.2435 | log_CO2=1.1748 | log_CO=0.8037 | log_CH4=0.6249 | log_NH3=1.0936
# Epoch 8/50 | Batch 4/4 | batch_loss=0.70797 | avg_loss=0.75101 | batch_time=0.02s
# Epoch 8/50 | train_loss=0.75101 | train_rmse_mean=1.19914 | val_rmse_mean=1.21630 | val_mae_mean=1.01284 | time=0.1s | lr=(1.00e-03, 8.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=1.5770 | log_CO2=1.3689 | log_CO=0.8772 | log_CH4=0.7852 | log_NH3=1.3873
# Validation RMSE | log_H2O=1.5113 | log_CO2=1.4420 | log_CO=0.9477 | log_CH4=0.9284 | log_NH3=1.2521
# Validation MAE  | log_H2O=1.2704 | log_CO2=1.2347 | log_CO=0.8154 | log_CH4=0.7330 | log_NH3=1.0108
# Epoch 9/50 | Batch 4/4 | batch_loss=0.78516 | avg_loss=0.72777 | batch_time=0.02s
# Epoch 9/50 | train_loss=0.72777 | train_rmse_mean=1.18234 | val_rmse_mean=1.20685 | val_mae_mean=1.01000 | time=0.1s | lr=(1.00e-03, 8.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=1.5654 | log_CO2=1.3679 | log_CO=0.8748 | log_CH4=0.8072 | log_NH3=1.2965
# Validation RMSE | log_H2O=1.4899 | log_CO2=1.4167 | log_CO=0.9109 | log_CH4=1.0316 | log_NH3=1.1851
# Validation MAE  | log_H2O=1.2559 | log_CO2=1.2098 | log_CO=0.7877 | log_CH4=0.8166 | log_NH3=0.9800
# Epoch 10/50 | Batch 4/4 | batch_loss=0.75791 | avg_loss=0.73432 | batch_time=0.02s
# Epoch 10/50 | train_loss=0.73432 | train_rmse_mean=1.20787 | val_rmse_mean=1.15596 | val_mae_mean=0.96299 | time=0.1s | lr=(1.00e-03, 8.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=1.5167 | log_CO2=1.3348 | log_CO=0.8706 | log_CH4=1.0204 | log_NH3=1.2969
# Validation RMSE | log_H2O=1.4654 | log_CO2=1.3715 | log_CO=0.9217 | log_CH4=0.8874 | log_NH3=1.1338
# Validation MAE  | log_H2O=1.2121 | log_CO2=1.1927 | log_CO=0.7940 | log_CH4=0.6807 | log_NH3=0.9353
# Epoch 11/50 | Batch 4/4 | batch_loss=0.65064 | avg_loss=0.68697 | batch_time=0.02s
# Epoch 11/50 | train_loss=0.68697 | train_rmse_mean=1.14789 | val_rmse_mean=1.11899 | val_mae_mean=0.93505 | time=0.1s | lr=(1.00e-03, 8.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=1.5115 | log_CO2=1.3051 | log_CO=0.8685 | log_CH4=0.8080 | log_NH3=1.2464
# Validation RMSE | log_H2O=1.4089 | log_CO2=1.3378 | log_CO=0.9256 | log_CH4=0.7878 | log_NH3=1.1348
# Validation MAE  | log_H2O=1.1815 | log_CO2=1.1529 | log_CO=0.7953 | log_CH4=0.5979 | log_NH3=0.9476
# Epoch 12/50 | Batch 4/4 | batch_loss=0.64528 | avg_loss=0.66022 | batch_time=0.02s
# Epoch 12/50 | train_loss=0.66022 | train_rmse_mean=1.11571 | val_rmse_mean=1.13737 | val_mae_mean=0.95108 | time=0.1s | lr=(1.00e-03, 8.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=1.5457 | log_CO2=1.2613 | log_CO=0.8646 | log_CH4=0.7072 | log_NH3=1.1998
# Validation RMSE | log_H2O=1.4708 | log_CO2=1.3628 | log_CO=0.9117 | log_CH4=0.8521 | log_NH3=1.0895
# Validation MAE  | log_H2O=1.2240 | log_CO2=1.1776 | log_CO=0.7843 | log_CH4=0.6733 | log_NH3=0.8962
# Epoch 13/50 | Batch 4/4 | batch_loss=0.70127 | avg_loss=0.62761 | batch_time=0.02s
# Epoch 13/50 | train_loss=0.62761 | train_rmse_mean=1.08723 | val_rmse_mean=1.22004 | val_mae_mean=1.00932 | time=0.1s | lr=(1.00e-03, 8.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=1.4590 | log_CO2=1.2262 | log_CO=0.8596 | log_CH4=0.7279 | log_NH3=1.1635
# Validation RMSE | log_H2O=1.5206 | log_CO2=1.3658 | log_CO=0.9090 | log_CH4=1.0480 | log_NH3=1.2567
# Validation MAE  | log_H2O=1.2242 | log_CO2=1.1210 | log_CO=0.7854 | log_CH4=0.8553 | log_NH3=1.0607
# Epoch 14/50 | Batch 4/4 | batch_loss=0.67752 | avg_loss=0.65309 | batch_time=0.02s
# Epoch 14/50 | train_loss=0.65309 | train_rmse_mean=1.11602 | val_rmse_mean=1.13763 | val_mae_mean=0.92861 | time=0.1s | lr=(1.00e-03, 8.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=1.4556 | log_CO2=1.2393 | log_CO=0.8507 | log_CH4=0.7657 | log_NH3=1.2688
# Validation RMSE | log_H2O=1.4574 | log_CO2=1.3866 | log_CO=0.9353 | log_CH4=0.8262 | log_NH3=1.0827
# Validation MAE  | log_H2O=1.2229 | log_CO2=1.1268 | log_CO=0.7992 | log_CH4=0.6078 | log_NH3=0.8864
# Epoch 15/50 | Batch 4/4 | batch_loss=0.60807 | avg_loss=0.62673 | batch_time=0.02s
# Epoch 15/50 | train_loss=0.62673 | train_rmse_mean=1.09048 | val_rmse_mean=1.14033 | val_mae_mean=0.94665 | time=0.1s | lr=(1.00e-03, 8.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=1.4808 | log_CO2=1.2472 | log_CO=0.8432 | log_CH4=0.7327 | log_NH3=1.1484
# Validation RMSE | log_H2O=1.4188 | log_CO2=1.3631 | log_CO=0.9226 | log_CH4=0.9030 | log_NH3=1.0941
# Validation MAE  | log_H2O=1.1765 | log_CO2=1.1419 | log_CO=0.7906 | log_CH4=0.7042 | log_NH3=0.9201
# Epoch 16/50 | Batch 4/4 | batch_loss=0.57654 | avg_loss=0.59217 | batch_time=0.02s
# Epoch 16/50 | train_loss=0.59217 | train_rmse_mean=1.06412 | val_rmse_mean=1.12129 | val_mae_mean=0.92795 | time=0.1s | lr=(1.00e-03, 8.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=1.4556 | log_CO2=1.1499 | log_CO=0.8306 | log_CH4=0.7576 | log_NH3=1.1269
# Validation RMSE | log_H2O=1.4302 | log_CO2=1.2805 | log_CO=0.9263 | log_CH4=0.7581 | log_NH3=1.2114
# Validation MAE  | log_H2O=1.1984 | log_CO2=1.0832 | log_CO=0.7962 | log_CH4=0.5548 | log_NH3=1.0070
# Epoch 17/50 | Batch 4/4 | batch_loss=0.56145 | avg_loss=0.57802 | batch_time=0.02s
# Epoch 17/50 | train_loss=0.57802 | train_rmse_mean=1.04195 | val_rmse_mean=1.14365 | val_mae_mean=0.93916 | time=0.1s | lr=(1.00e-03, 8.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=1.3816 | log_CO2=1.1580 | log_CO=0.8378 | log_CH4=0.7135 | log_NH3=1.1188
# Validation RMSE | log_H2O=1.4021 | log_CO2=1.2753 | log_CO=0.9532 | log_CH4=0.9336 | log_NH3=1.1540
# Validation MAE  | log_H2O=1.1665 | log_CO2=1.0901 | log_CO=0.8136 | log_CH4=0.7217 | log_NH3=0.9039
# Epoch 18/50 | Batch 4/4 | batch_loss=0.55772 | avg_loss=0.55347 | batch_time=0.02s
# Epoch 18/50 | train_loss=0.55347 | train_rmse_mean=1.01634 | val_rmse_mean=1.15549 | val_mae_mean=0.95689 | time=0.1s | lr=(5.00e-04, 4.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=1.3001 | log_CO2=1.1059 | log_CO=0.8340 | log_CH4=0.7114 | log_NH3=1.1303
# Validation RMSE | log_H2O=1.3864 | log_CO2=1.2681 | log_CO=0.9402 | log_CH4=0.8178 | log_NH3=1.3649
# Validation MAE  | log_H2O=1.1797 | log_CO2=1.0550 | log_CO=0.7978 | log_CH4=0.6071 | log_NH3=1.1448
# Epoch 19/50 | Batch 4/4 | batch_loss=0.57049 | avg_loss=0.53316 | batch_time=0.02s
# Epoch 19/50 | train_loss=0.53316 | train_rmse_mean=0.98941 | val_rmse_mean=1.07342 | val_mae_mean=0.87965 | time=0.1s | lr=(5.00e-04, 4.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=1.2884 | log_CO2=1.1036 | log_CO=0.8153 | log_CH4=0.6163 | log_NH3=1.1235
# Validation RMSE | log_H2O=1.2955 | log_CO2=1.2661 | log_CO=0.9402 | log_CH4=0.7609 | log_NH3=1.1045
# Validation MAE  | log_H2O=1.0780 | log_CO2=1.0760 | log_CO=0.7930 | log_CH4=0.5612 | log_NH3=0.8900
# Epoch 20/50 | Batch 4/4 | batch_loss=0.55869 | avg_loss=0.52200 | batch_time=0.02s
# Epoch 20/50 | train_loss=0.52200 | train_rmse_mean=0.96940 | val_rmse_mean=1.07223 | val_mae_mean=0.87388 | time=0.1s | lr=(5.00e-04, 4.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=1.2350 | log_CO2=1.1230 | log_CO=0.8193 | log_CH4=0.5716 | log_NH3=1.0981
# Validation RMSE | log_H2O=1.3691 | log_CO2=1.2845 | log_CO=0.9224 | log_CH4=0.7398 | log_NH3=1.0454
# Validation MAE  | log_H2O=1.1363 | log_CO2=1.0456 | log_CO=0.7711 | log_CH4=0.5610 | log_NH3=0.8554
# Epoch 21/50 | Batch 4/4 | batch_loss=0.52045 | avg_loss=0.50156 | batch_time=0.02s
# Epoch 21/50 | train_loss=0.50156 | train_rmse_mean=0.95306 | val_rmse_mean=1.06580 | val_mae_mean=0.88163 | time=0.1s | lr=(5.00e-04, 4.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=1.2026 | log_CO2=1.0996 | log_CO=0.8093 | log_CH4=0.5991 | log_NH3=1.0547
# Validation RMSE | log_H2O=1.2733 | log_CO2=1.2661 | log_CO=0.9591 | log_CH4=0.7671 | log_NH3=1.0634
# Validation MAE  | log_H2O=1.0699 | log_CO2=1.0523 | log_CO=0.8191 | log_CH4=0.5916 | log_NH3=0.8752
# Epoch 22/50 | Batch 4/4 | batch_loss=0.52475 | avg_loss=0.49388 | batch_time=0.02s
# Epoch 22/50 | train_loss=0.49388 | train_rmse_mean=0.95143 | val_rmse_mean=1.07357 | val_mae_mean=0.88413 | time=0.1s | lr=(5.00e-04, 4.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=1.2337 | log_CO2=1.0868 | log_CO=0.7998 | log_CH4=0.6239 | log_NH3=1.0129
# Validation RMSE | log_H2O=1.2933 | log_CO2=1.2168 | log_CO=0.9513 | log_CH4=0.8635 | log_NH3=1.0431
# Validation MAE  | log_H2O=1.0548 | log_CO2=1.0225 | log_CO=0.8129 | log_CH4=0.6825 | log_NH3=0.8480
# Epoch 23/50 | Batch 4/4 | batch_loss=0.53633 | avg_loss=0.48274 | batch_time=0.02s
# Epoch 23/50 | train_loss=0.48274 | train_rmse_mean=0.93927 | val_rmse_mean=1.03322 | val_mae_mean=0.84752 | time=0.1s | lr=(5.00e-04, 4.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=1.1957 | log_CO2=1.0707 | log_CO=0.7982 | log_CH4=0.6286 | log_NH3=1.0031
# Validation RMSE | log_H2O=1.2476 | log_CO2=1.2464 | log_CO=0.9149 | log_CH4=0.7340 | log_NH3=1.0231
# Validation MAE  | log_H2O=1.0498 | log_CO2=1.0365 | log_CO=0.7731 | log_CH4=0.5394 | log_NH3=0.8388
# Epoch 24/50 | Batch 4/4 | batch_loss=0.43998 | avg_loss=0.46054 | batch_time=0.02s
# Epoch 24/50 | train_loss=0.46054 | train_rmse_mean=0.90541 | val_rmse_mean=1.05958 | val_mae_mean=0.86876 | time=0.1s | lr=(5.00e-04, 4.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=1.1363 | log_CO2=1.0651 | log_CO=0.8022 | log_CH4=0.5761 | log_NH3=0.9473
# Validation RMSE | log_H2O=1.2498 | log_CO2=1.2456 | log_CO=0.9241 | log_CH4=0.8425 | log_NH3=1.0360
# Validation MAE  | log_H2O=1.0286 | log_CO2=1.0320 | log_CO=0.7758 | log_CH4=0.6240 | log_NH3=0.8833
# Epoch 25/50 | Batch 4/4 | batch_loss=0.42182 | avg_loss=0.45508 | batch_time=0.02s
# Epoch 25/50 | train_loss=0.45508 | train_rmse_mean=0.90608 | val_rmse_mean=1.03772 | val_mae_mean=0.85089 | time=0.1s | lr=(5.00e-04, 4.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=1.1396 | log_CO2=1.0514 | log_CO=0.7896 | log_CH4=0.6026 | log_NH3=0.9473
# Validation RMSE | log_H2O=1.2937 | log_CO2=1.2061 | log_CO=0.9535 | log_CH4=0.7328 | log_NH3=1.0026
# Validation MAE  | log_H2O=1.0727 | log_CO2=1.0118 | log_CO=0.8077 | log_CH4=0.5291 | log_NH3=0.8331
# Epoch 26/50 | Batch 4/4 | batch_loss=0.41883 | avg_loss=0.42751 | batch_time=0.02s
# Epoch 26/50 | train_loss=0.42751 | train_rmse_mean=0.87287 | val_rmse_mean=1.01644 | val_mae_mean=0.82957 | time=0.1s | lr=(5.00e-04, 4.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=1.0640 | log_CO2=1.0207 | log_CO=0.7737 | log_CH4=0.5712 | log_NH3=0.9347
# Validation RMSE | log_H2O=1.1651 | log_CO2=1.2605 | log_CO=0.9065 | log_CH4=0.7235 | log_NH3=1.0266
# Validation MAE  | log_H2O=0.9673 | log_CO2=1.0521 | log_CO=0.7695 | log_CH4=0.5217 | log_NH3=0.8372
# Epoch 27/50 | Batch 4/4 | batch_loss=0.43879 | avg_loss=0.42828 | batch_time=0.02s
# Epoch 27/50 | train_loss=0.42828 | train_rmse_mean=0.87583 | val_rmse_mean=1.03063 | val_mae_mean=0.84303 | time=0.1s | lr=(5.00e-04, 4.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=1.0751 | log_CO2=1.0296 | log_CO=0.7700 | log_CH4=0.5792 | log_NH3=0.9253
# Validation RMSE | log_H2O=1.1804 | log_CO2=1.2072 | log_CO=0.8832 | log_CH4=0.7494 | log_NH3=1.1330
# Validation MAE  | log_H2O=0.9654 | log_CO2=1.0129 | log_CO=0.7393 | log_CH4=0.5457 | log_NH3=0.9519
# Epoch 28/50 | Batch 4/4 | batch_loss=0.36669 | avg_loss=0.41011 | batch_time=0.02s
# Epoch 28/50 | train_loss=0.41011 | train_rmse_mean=0.85701 | val_rmse_mean=0.99393 | val_mae_mean=0.81324 | time=0.1s | lr=(5.00e-04, 4.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=1.0696 | log_CO2=1.0123 | log_CO=0.7570 | log_CH4=0.5724 | log_NH3=0.8737
# Validation RMSE | log_H2O=1.2035 | log_CO2=1.1312 | log_CO=0.8741 | log_CH4=0.7046 | log_NH3=1.0562
# Validation MAE  | log_H2O=1.0015 | log_CO2=0.9460 | log_CO=0.7366 | log_CH4=0.5076 | log_NH3=0.8745
# Epoch 29/50 | Batch 4/4 | batch_loss=0.34788 | avg_loss=0.41313 | batch_time=0.02s
# Epoch 29/50 | train_loss=0.41313 | train_rmse_mean=0.87048 | val_rmse_mean=1.05791 | val_mae_mean=0.85728 | time=0.1s | lr=(5.00e-04, 4.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=1.1502 | log_CO2=0.9848 | log_CO=0.7361 | log_CH4=0.5763 | log_NH3=0.9051
# Validation RMSE | log_H2O=1.2929 | log_CO2=1.0944 | log_CO=0.8680 | log_CH4=0.7721 | log_NH3=1.2620
# Validation MAE  | log_H2O=1.0540 | log_CO2=0.9139 | log_CO=0.7007 | log_CH4=0.5815 | log_NH3=1.0363
# Epoch 30/50 | Batch 4/4 | batch_loss=0.40196 | avg_loss=0.40798 | batch_time=0.02s
# Epoch 30/50 | train_loss=0.40798 | train_rmse_mean=0.85485 | val_rmse_mean=0.98242 | val_mae_mean=0.80477 | time=0.1s | lr=(5.00e-04, 4.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=1.0441 | log_CO2=0.9631 | log_CO=0.7629 | log_CH4=0.5851 | log_NH3=0.9191
# Validation RMSE | log_H2O=1.2128 | log_CO2=1.0797 | log_CO=0.8846 | log_CH4=0.6840 | log_NH3=1.0510
# Validation MAE  | log_H2O=1.0026 | log_CO2=0.9207 | log_CO=0.7368 | log_CH4=0.5022 | log_NH3=0.8616
# Epoch 31/50 | Batch 4/4 | batch_loss=0.39061 | avg_loss=0.38557 | batch_time=0.02s
# Epoch 31/50 | train_loss=0.38557 | train_rmse_mean=0.83274 | val_rmse_mean=1.01121 | val_mae_mean=0.82887 | time=0.1s | lr=(5.00e-04, 4.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=1.0434 | log_CO2=0.9770 | log_CO=0.7369 | log_CH4=0.5775 | log_NH3=0.8288
# Validation RMSE | log_H2O=1.2788 | log_CO2=1.1922 | log_CO=0.8909 | log_CH4=0.7165 | log_NH3=0.9777
# Validation MAE  | log_H2O=1.0677 | log_CO2=1.0182 | log_CO=0.7362 | log_CH4=0.5300 | log_NH3=0.7923
# Epoch 32/50 | Batch 4/4 | batch_loss=0.36992 | avg_loss=0.37255 | batch_time=0.02s
# Epoch 32/50 | train_loss=0.37255 | train_rmse_mean=0.81842 | val_rmse_mean=0.99982 | val_mae_mean=0.81425 | time=0.1s | lr=(5.00e-04, 4.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=1.0443 | log_CO2=0.9502 | log_CO=0.7152 | log_CH4=0.5296 | log_NH3=0.8528
# Validation RMSE | log_H2O=1.2198 | log_CO2=1.0775 | log_CO=0.8689 | log_CH4=0.7322 | log_NH3=1.1008
# Validation MAE  | log_H2O=1.0002 | log_CO2=0.9072 | log_CO=0.6994 | log_CH4=0.5516 | log_NH3=0.9129
# Epoch 33/50 | Batch 4/4 | batch_loss=0.33823 | avg_loss=0.35439 | batch_time=0.02s
# Epoch 33/50 | train_loss=0.35439 | train_rmse_mean=0.79792 | val_rmse_mean=0.95478 | val_mae_mean=0.76973 | time=0.1s | lr=(5.00e-04, 4.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=0.9887 | log_CO2=0.9238 | log_CO=0.6966 | log_CH4=0.5205 | log_NH3=0.8601
# Validation RMSE | log_H2O=1.1524 | log_CO2=1.0421 | log_CO=0.8522 | log_CH4=0.6945 | log_NH3=1.0327
# Validation MAE  | log_H2O=0.9215 | log_CO2=0.8897 | log_CO=0.6767 | log_CH4=0.5195 | log_NH3=0.8413
# Epoch 34/50 | Batch 4/4 | batch_loss=0.39289 | avg_loss=0.33783 | batch_time=0.02s
# Epoch 34/50 | train_loss=0.33783 | train_rmse_mean=0.77393 | val_rmse_mean=0.97876 | val_mae_mean=0.78921 | time=0.1s | lr=(5.00e-04, 4.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=0.9590 | log_CO2=0.9281 | log_CO=0.6909 | log_CH4=0.5010 | log_NH3=0.7906
# Validation RMSE | log_H2O=1.2158 | log_CO2=1.0471 | log_CO=0.8787 | log_CH4=0.7589 | log_NH3=0.9933
# Validation MAE  | log_H2O=0.9793 | log_CO2=0.8768 | log_CO=0.7037 | log_CH4=0.5972 | log_NH3=0.7891
# Epoch 35/50 | Batch 4/4 | batch_loss=0.41254 | avg_loss=0.35151 | batch_time=0.02s
# Epoch 35/50 | train_loss=0.35151 | train_rmse_mean=0.79210 | val_rmse_mean=1.00950 | val_mae_mean=0.82261 | time=0.1s | lr=(5.00e-04, 4.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=0.9436 | log_CO2=0.9285 | log_CO=0.7013 | log_CH4=0.5327 | log_NH3=0.8544
# Validation RMSE | log_H2O=1.1935 | log_CO2=1.2058 | log_CO=0.8982 | log_CH4=0.7191 | log_NH3=1.0309
# Validation MAE  | log_H2O=0.9872 | log_CO2=1.0200 | log_CO=0.7239 | log_CH4=0.5356 | log_NH3=0.8465
# Epoch 36/50 | Batch 4/4 | batch_loss=0.39661 | avg_loss=0.35593 | batch_time=0.02s
# Epoch 36/50 | train_loss=0.35593 | train_rmse_mean=0.79951 | val_rmse_mean=0.99589 | val_mae_mean=0.79961 | time=0.1s | lr=(5.00e-04, 4.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=1.0391 | log_CO2=0.9890 | log_CO=0.6852 | log_CH4=0.5021 | log_NH3=0.7821
# Validation RMSE | log_H2O=1.3248 | log_CO2=1.0581 | log_CO=0.8854 | log_CH4=0.6839 | log_NH3=1.0273
# Validation MAE  | log_H2O=1.0765 | log_CO2=0.8667 | log_CO=0.7238 | log_CH4=0.4971 | log_NH3=0.8340
# Epoch 37/50 | Batch 4/4 | batch_loss=0.35691 | avg_loss=0.35658 | batch_time=0.02s
# Epoch 37/50 | train_loss=0.35658 | train_rmse_mean=0.80252 | val_rmse_mean=0.99233 | val_mae_mean=0.81420 | time=0.1s | lr=(5.00e-04, 4.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=1.0609 | log_CO2=0.9346 | log_CO=0.6913 | log_CH4=0.5053 | log_NH3=0.8205
# Validation RMSE | log_H2O=1.2273 | log_CO2=0.9906 | log_CO=0.8745 | log_CH4=0.7011 | log_NH3=1.1682
# Validation MAE  | log_H2O=1.0089 | log_CO2=0.8424 | log_CO=0.7036 | log_CH4=0.5370 | log_NH3=0.9791
# Epoch 38/50 | Batch 4/4 | batch_loss=0.28623 | avg_loss=0.33843 | batch_time=0.02s
# Epoch 38/50 | train_loss=0.33843 | train_rmse_mean=0.78269 | val_rmse_mean=0.97066 | val_mae_mean=0.78633 | time=0.1s | lr=(5.00e-04, 4.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=0.9506 | log_CO2=0.8525 | log_CO=0.6775 | log_CH4=0.5273 | log_NH3=0.9056
# Validation RMSE | log_H2O=1.2110 | log_CO2=1.0880 | log_CO=0.8486 | log_CH4=0.6756 | log_NH3=1.0302
# Validation MAE  | log_H2O=1.0043 | log_CO2=0.9517 | log_CO=0.6663 | log_CH4=0.4928 | log_NH3=0.8165
# Epoch 39/50 | Batch 4/4 | batch_loss=0.27774 | avg_loss=0.33716 | batch_time=0.02s
# Epoch 39/50 | train_loss=0.33716 | train_rmse_mean=0.78417 | val_rmse_mean=0.97203 | val_mae_mean=0.78202 | time=0.1s | lr=(5.00e-04, 4.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=0.9401 | log_CO2=0.8680 | log_CO=0.6573 | log_CH4=0.5207 | log_NH3=0.9347
# Validation RMSE | log_H2O=1.1387 | log_CO2=0.9810 | log_CO=0.8498 | log_CH4=0.6555 | log_NH3=1.2351
# Validation MAE  | log_H2O=0.9099 | log_CO2=0.8384 | log_CO=0.6578 | log_CH4=0.4744 | log_NH3=1.0296
# Runtime budget reached during epoch 40; evaluating current model state.
# Epoch 40/50 | train_loss=0.36551 | train_rmse_mean=0.81916 | val_rmse_mean=0.97661 | val_mae_mean=0.79007 | time=0.1s | lr=(2.50e-04, 2.00e-04, 0.00e+00) | quantum_active=False | quantum_scale=0.00 | backbone_frozen=False
# Train RMSE      | log_H2O=0.9698 | log_CO2=0.9446 | log_CO=0.6795 | log_CH4=0.5643 | log_NH3=0.9376
# Validation RMSE | log_H2O=1.1417 | log_CO2=0.9730 | log_CO=0.8569 | log_CH4=0.6523 | log_NH3=1.2590
# Validation MAE  | log_H2O=0.9347 | log_CO2=0.8396 | log_CO=0.6568 | log_CH4=0.4702 | log_NH3=1.0491
# {
#   "status": "stopped_runtime",
#   "best_epoch": 33,
#   "best_val_rmse_mean": 0.9547767639160156,
#   "validation_rmse_mean": 0.9547767639160156,
#   "validation_mae_mean": 0.769727349281311,
#   "holdout_rmse_mean": 0.885480523109436,
#   "holdout_mae_mean": 0.7213555574417114,
#   "runtime_seconds": 4.0684900830019615,
#   "max_runtime_seconds": 4.0,
#   "testdata_rows": 685,
#   "output_dir": "/Users/jkw/Documents/uni/axion/hack4sages/ariel/models/notebooks/outputs/fair_small_compare/20260312_000541/codex/stage1_classical",
#   "dataset": {
#     "aux_columns": [
#       "star_distance",
#       "star_mass_kg",
#       "star_radius_m",
#       "star_temperature",
#       "planet_mass_kg",
#       "planet_orbital_period",
#       "planet_distance",
#       "planet_surface_gravity"
#     ],
#     "fixed_spectral_channels": [
#       "instrument_width",
#       "instrument_wlgrid"
#     ],
#     "holdout_rows": 64,
#     "log10_aux_columns": [
#       "star_distance",
#       "star_mass_kg",
#       "star_radius_m",
#       "planet_mass_kg",
#       "planet_orbital_period",
#       "planet_distance",
#       "planet_surface_gravity"
#     ],
#     "model_spectral_channels": [
#       "instrument_spectrum",
#       "instrument_noise",
#       "instrument_width_template",
#       "wavelength_um"
#     ],
#     "model_spectrum_shape": [
#       4,
#       52
#     ],
#     "presence_threshold_log10_vmr": -8.0,
#     "primary_stratify_mode": "presence_signature",
#     "raw_spectral_channels": [
#       "instrument_spectrum",
#       "instrument_noise",
#       "instrument_width",
#       "instrument_wlgrid"
#     ],
#     "raw_spectrum_shape": [
#       52,
#       4
#     ],
#     "rows_total": 41423,
#     "sample_spectral_channels": [
#       "instrument_spectrum",
#       "instrument_noise"
#     ],
#     "sample_spectral_normalization": {
#       "applied_channels": [
#         "instrument_spectrum",
#         "instrument_noise"
#       ],
#       "mode": "divide_by_sample_mean",
#       "reference_channel": "instrument_spectrum"
#     },
#     "secondary_stratify_mode": "unstratified",
#     "shared_split_file": "/Users/jkw/Documents/uni/axion/hack4sages/ariel/models/notebooks/outputs/fair_small_compare/20260312_000541/shared_split.csv",
#     "split_fractions": {
#       "holdout": 0.1,
#       "train": 0.8,
#       "val": 0.1
#     },
#     "split_seed": 42,
#     "target_columns": [
#       "log_H2O",
#       "log_CO2",
#       "log_CO",
#       "log_CH4",
#       "log_NH3"
#     ],
#     "testdata_rows": 685,
#     "testdata_rows_total": 685,
#     "train_rows": 256,
#     "val_rows": 64,
#     "wavelength_bins": 52,
#     "wavelength_max_um": 7.275559425354004,
#     "wavelength_min_um": 0.550000011920929
#   }
# }
# {
#   "project_root": "/Users/jkw/Documents/uni/axion/hack4sages/ariel/models/notebooks",
#   "data_root": "/Users/jkw/Documents/uni/axion/hack4sages/ariel",
#   "output_dir": "/Users/jkw/Documents/uni/axion/hack4sages/ariel/models/notebooks/outputs/fair_small_compare/20260312_000541/codex/stage2_hybrid",
#   "prepared_cache_dir": "/Users/jkw/Documents/uni/axion/hack4sages/ariel/models/notebooks/outputs/fair_small_compare/20260312_000541/codex_prepared_cache",
#   "init_checkpoint_path": "/Users/jkw/Documents/uni/axion/hack4sages/ariel/models/notebooks/outputs/fair_small_compare/20260312_000541/codex/stage1_classical/best_model.pt",
#   "seed": 42,
#   "batch_size": 16,
#   "eval_batch_size": 32,
#   "max_epochs": 50,
#   "max_runtime_seconds": 15.80789924999408,
#   "early_stop_patience": 50,
#   "scheduler_patience": 6,
#   "scheduler_factor": 0.5,
#   "classical_lr": 5e-05,
#   "quantum_lr": 0.0002,
#   "weight_decay": 0.0001,
#   "gradient_clip_norm": 5.0,
#   "dropout": 0.05,
#   "loss_name": "mse",
#   "qnn_qubits": 12,
#   "qnn_depth": 2,
#   "qnn_init_scale": 0.1,
#   "quantum_device": "lightning.qubit",
#   "quantum_use_async": false,
#   "classical_only": false,
#   "quantum_warmup_epochs": 0,
#   "quantum_ramp_epochs": 10,
#   "quantum_backbone_freeze_epochs": 4,
#   "use_amp": false,
#   "log_every_batches": 10,
#   "train_limit": 256,
#   "val_limit": 64,
#   "holdout_limit": 64,
#   "test_limit": null,
#   "aux_columns": [
#     "star_distance",
#     "star_mass_kg",
#     "star_radius_m",
#     "star_temperature",
#     "planet_mass_kg",
#     "planet_orbital_period",
#     "planet_distance",
#     "planet_surface_gravity"
#   ],
#   "target_columns": [
#     "log_H2O",
#     "log_CO2",
#     "log_CO",
#     "log_CH4",
#     "log_NH3"
#   ]
# }
# Project root: /Users/jkw/Documents/uni/axion/hack4sages/ariel/models/notebooks
# Data root: /Users/jkw/Documents/uni/axion/hack4sages/ariel
# Output dir: /Users/jkw/Documents/uni/axion/hack4sages/ariel/models/notebooks/outputs/fair_small_compare/20260312_000541/codex/stage2_hybrid
# Batch size: 16
# Eval batch size: 32
# Quantum width/depth: 12/2
# Quantum async: False
# Loss: mse
# Quantum warmup epochs: 0
# Quantum ramp epochs: 10
# Quantum backbone freeze epochs: 4
# Prepared cache dir: /Users/jkw/Documents/uni/axion/hack4sages/ariel/models/notebooks/outputs/fair_small_compare/20260312_000541/codex_prepared_cache
# Initialized from checkpoint: /Users/jkw/Documents/uni/axion/hack4sages/ariel/models/notebooks/outputs/fair_small_compare/20260312_000541/codex/stage1_classical/best_model.pt | loaded_keys=55 | missing=11 | unexpected=0
# Missing checkpoint keys: projector.net.0.weight, projector.net.0.bias, projector.net.3.weight, projector.net.3.bias, projector.net.4.weight, projector.net.4.bias, quantum_block.weights, quantum_head.net.0.weight, quantum_head.net.0.bias, quantum_head.net.3.weight, quantum_head.net.3.bias
# Torch device: cpu | Quantum device: lightning.qubit | classical_only=False
# Loss: mse | Quantum warmup epochs: 0 | Quantum ramp epochs: 10 | Backbone freeze epochs: 4
# Max runtime seconds: 15.8
# Epoch 1/50 | Batch 10/16 | batch_loss=0.29702 | avg_loss=0.34660 | batch_time=0.14s
# Epoch 1/50 | Batch 16/16 | batch_loss=0.30086 | avg_loss=0.33068 | batch_time=0.14s
# Epoch 1/50 | train_loss=0.33068 | train_rmse_mean=0.77027 | val_rmse_mean=0.95477 | val_mae_mean=0.76972 | time=2.9s | lr=(5.00e-05, 2.00e-04, 2.00e-04) | quantum_active=True | quantum_scale=0.10 | backbone_frozen=True
# Train RMSE      | log_H2O=0.9500 | log_CO2=0.9028 | log_CO=0.6801 | log_CH4=0.5224 | log_NH3=0.7960
# Validation RMSE | log_H2O=1.1523 | log_CO2=1.0421 | log_CO=0.8522 | log_CH4=0.6945 | log_NH3=1.0327
# Validation MAE  | log_H2O=0.9215 | log_CO2=0.8897 | log_CO=0.6767 | log_CH4=0.5195 | log_NH3=0.8413
# Epoch 2/50 | Batch 10/16 | batch_loss=0.37985 | avg_loss=0.33377 | batch_time=0.14s
# Epoch 2/50 | Batch 16/16 | batch_loss=0.32064 | avg_loss=0.33449 | batch_time=0.14s
# Epoch 2/50 | train_loss=0.33449 | train_rmse_mean=0.77389 | val_rmse_mean=0.95472 | val_mae_mean=0.76967 | time=2.8s | lr=(5.00e-05, 2.00e-04, 2.00e-04) | quantum_active=True | quantum_scale=0.20 | backbone_frozen=True
# Train RMSE      | log_H2O=0.9893 | log_CO2=0.9035 | log_CO=0.6877 | log_CH4=0.5166 | log_NH3=0.7723
# Validation RMSE | log_H2O=1.1521 | log_CO2=1.0421 | log_CO=0.8522 | log_CH4=0.6945 | log_NH3=1.0326
# Validation MAE  | log_H2O=0.9213 | log_CO2=0.8897 | log_CO=0.6767 | log_CH4=0.5195 | log_NH3=0.8413
# Epoch 3/50 | Batch 10/16 | batch_loss=0.33636 | avg_loss=0.32379 | batch_time=0.14s
# Epoch 3/50 | Batch 16/16 | batch_loss=0.33248 | avg_loss=0.32911 | batch_time=0.14s
# Epoch 3/50 | train_loss=0.32911 | train_rmse_mean=0.76808 | val_rmse_mean=0.95453 | val_mae_mean=0.76952 | time=2.7s | lr=(5.00e-05, 2.00e-04, 2.00e-04) | quantum_active=True | quantum_scale=0.30 | backbone_frozen=True
# Train RMSE      | log_H2O=0.9705 | log_CO2=0.9019 | log_CO=0.6755 | log_CH4=0.5027 | log_NH3=0.7897
# Validation RMSE | log_H2O=1.1513 | log_CO2=1.0421 | log_CO=0.8523 | log_CH4=0.6945 | log_NH3=1.0325
# Validation MAE  | log_H2O=0.9206 | log_CO2=0.8897 | log_CO=0.6767 | log_CH4=0.5195 | log_NH3=0.8411
# Epoch 4/50 | Batch 10/16 | batch_loss=0.26512 | avg_loss=0.32208 | batch_time=0.14s
# Epoch 4/50 | Batch 16/16 | batch_loss=0.32018 | avg_loss=0.33619 | batch_time=0.17s
# Epoch 4/50 | train_loss=0.33619 | train_rmse_mean=0.77508 | val_rmse_mean=0.95410 | val_mae_mean=0.76915 | time=2.8s | lr=(5.00e-05, 2.00e-04, 2.00e-04) | quantum_active=True | quantum_scale=0.40 | backbone_frozen=True
# Train RMSE      | log_H2O=0.9784 | log_CO2=0.9019 | log_CO=0.6931 | log_CH4=0.5229 | log_NH3=0.7792
# Validation RMSE | log_H2O=1.1493 | log_CO2=1.0421 | log_CO=0.8523 | log_CH4=0.6946 | log_NH3=1.0322
# Validation MAE  | log_H2O=0.9189 | log_CO2=0.8897 | log_CO=0.6768 | log_CH4=0.5195 | log_NH3=0.8408
# Epoch 5/50 | Batch 10/16 | batch_loss=0.44790 | avg_loss=0.34622 | batch_time=0.15s
# Epoch 5/50 | Batch 16/16 | batch_loss=0.34312 | avg_loss=0.33520 | batch_time=0.15s
# Epoch 5/50 | train_loss=0.33520 | train_rmse_mean=0.77384 | val_rmse_mean=0.96473 | val_mae_mean=0.78817 | time=3.0s | lr=(5.00e-05, 2.00e-04, 2.00e-04) | quantum_active=True | quantum_scale=0.50 | backbone_frozen=False
# Train RMSE      | log_H2O=0.9812 | log_CO2=0.8986 | log_CO=0.6865 | log_CH4=0.5029 | log_NH3=0.7999
# Validation RMSE | log_H2O=1.1533 | log_CO2=1.0528 | log_CO=0.8607 | log_CH4=0.7449 | log_NH3=1.0118
# Validation MAE  | log_H2O=0.9418 | log_CO2=0.8999 | log_CO=0.6856 | log_CH4=0.5822 | log_NH3=0.8313
# Epoch 6/50 | Batch 10/16 | batch_loss=0.37535 | avg_loss=0.33173 | batch_time=0.15s
# Runtime budget reached during epoch 6; evaluating current model state.
# Epoch 6/50 | train_loss=0.33463 | train_rmse_mean=0.77261 | val_rmse_mean=0.94194 | val_mae_mean=0.75961 | time=2.1s | lr=(5.00e-05, 2.00e-04, 2.00e-04) | quantum_active=True | quantum_scale=0.60 | backbone_frozen=False
# Train RMSE      | log_H2O=0.9054 | log_CO2=0.9289 | log_CO=0.6847 | log_CH4=0.5343 | log_NH3=0.8097
# Validation RMSE | log_H2O=1.1434 | log_CO2=1.0539 | log_CO=0.8478 | log_CH4=0.6801 | log_NH3=0.9846
# Validation MAE  | log_H2O=0.9318 | log_CO2=0.9041 | log_CO=0.6688 | log_CH4=0.5023 | log_NH3=0.7910
# {
#   "status": "stopped_runtime",
#   "best_epoch": 6,
#   "best_val_rmse_mean": 0.9419435262680054,
#   "validation_rmse_mean": 0.9422310590744019,
#   "validation_mae_mean": 0.760151743888855,
#   "holdout_rmse_mean": 0.8886178731918335,
#   "holdout_mae_mean": 0.7159059643745422,
#   "runtime_seconds": 16.281665291004174,
#   "max_runtime_seconds": 15.80789924999408,
#   "testdata_rows": 685,
#   "output_dir": "/Users/jkw/Documents/uni/axion/hack4sages/ariel/models/notebooks/outputs/fair_small_compare/20260312_000541/codex/stage2_hybrid",
#   "dataset": {
#     "aux_columns": [
#       "star_distance",
#       "star_mass_kg",
#       "star_radius_m",
#       "star_temperature",
#       "planet_mass_kg",
#       "planet_orbital_period",
#       "planet_distance",
#       "planet_surface_gravity"
#     ],
#     "fixed_spectral_channels": [
#       "instrument_width",
#       "instrument_wlgrid"
#     ],
#     "holdout_rows": 64,
#     "log10_aux_columns": [
#       "star_distance",
#       "star_mass_kg",
#       "star_radius_m",
#       "planet_mass_kg",
#       "planet_orbital_period",
#       "planet_distance",
#       "planet_surface_gravity"
#     ],
#     "model_spectral_channels": [
#       "instrument_spectrum",
#       "instrument_noise",
#       "instrument_width_template",
#       "wavelength_um"
#     ],
#     "model_spectrum_shape": [
#       4,
#       52
#     ],
#     "presence_threshold_log10_vmr": -8.0,
#     "primary_stratify_mode": "presence_signature",
#     "raw_spectral_channels": [
#       "instrument_spectrum",
#       "instrument_noise",
#       "instrument_width",
#       "instrument_wlgrid"
#     ],
#     "raw_spectrum_shape": [
#       52,
#       4
#     ],
#     "rows_total": 41423,
#     "sample_spectral_channels": [
#       "instrument_spectrum",
#       "instrument_noise"
#     ],
#     "sample_spectral_normalization": {
#       "applied_channels": [
#         "instrument_spectrum",
#         "instrument_noise"
#       ],
#       "mode": "divide_by_sample_mean",
#       "reference_channel": "instrument_spectrum"
#     },
#     "secondary_stratify_mode": "unstratified",
#     "shared_split_file": "/Users/jkw/Documents/uni/axion/hack4sages/ariel/models/notebooks/outputs/fair_small_compare/20260312_000541/shared_split.csv",
#     "split_fractions": {
#       "holdout": 0.1,
#       "train": 0.8,
#       "val": 0.1
#     },
#     "split_seed": 42,
#     "target_columns": [
#       "log_H2O",
#       "log_CO2",
#       "log_CO",
#       "log_CH4",
#       "log_NH3"
#     ],
#     "testdata_rows": 685,
#     "testdata_rows_total": 685,
#     "train_rows": 256,
#     "val_rows": 64,
#     "wavelength_bins": 52,
#     "wavelength_max_um": 7.275559425354004,
#     "wavelength_min_um": 0.550000011920929
#   }
# }
# {'model': 'codex_two_stage_12q',
#  'best_epoch': 6,
#  'best_val_rmse_mean': 0.9419435262680054,
#  'validation_rmse_mean': 0.9422310590744019,
#  'holdout_rmse_mean': 0.8886178731918335,
#  'validation_rmse': {'log_H2O': 1.1451952457427979,
#   'log_CO2': 1.053962230682373,
#   'log_CO': 0.8478689789772034,
#   'log_CH4': 0.6800680756568909,
#   'log_NH3': 0.9840610027313232},
#  'holdout_rmse': {'log_H2O': 1.1235545873641968,
#   'log_CO2': 0.9729803204536438,
#   'log_CO': 0.7566131353378296,
#   'log_CH4': 0.6400355100631714,
#   'log_NH3': 0.9499058723449707},
#  'hyperparameters': {'qnn_qubits': 12,
#   'qnn_depth': 2,
#   'total_runtime_budget_seconds': 20.0,
#   'stage1_runtime_budget_seconds': 4.0,
#   'stage2_runtime_budget_seconds': 15.80789924999408,
#   'stage1_batch_size': 64,
#   'stage1_epochs': 50,
#   'stage1_classical_lr': 0.001,
#   'stage2_batch_size': 16,
#   'stage2_epochs': 50,
#   'stage2_classical_lr': 5e-05,
#   'stage2_quantum_lr': 0.0002,
#   'stage2_quantum_ramp_epochs': 10,
#   'stage2_quantum_backbone_freeze_epochs': 4},
#  'stage1_summary': {'status': 'stopped_runtime',
#   'best_epoch': 33,
#   'best_val_rmse_mean': 0.9547767639160156,
#   'validation_rmse_mean': 0.9547767639160156,
#   'validation_mae_mean': 0.769727349281311,
#   'holdout_rmse_mean': 0.885480523109436,
#   'holdout_mae_mean': 0.7213555574417114,
#   'runtime_seconds': 4.0684900830019615,
#   'max_runtime_seconds': 4.0,
#   'testdata_rows': 685,
#   'output_dir': '/Users/jkw/Documents/uni/axion/hack4sages/ariel/models/notebooks/outputs/fair_small_compare/20260312_000541/codex/stage1_classical',
#   'dataset': {'aux_columns': ['star_distance',
#     'star_mass_kg',
#     'star_radius_m',
#     'star_temperature',
#     'planet_mass_kg',
#     'planet_orbital_period',
#     'planet_distance',
#     'planet_surface_gravity'],
#    'fixed_spectral_channels': ['instrument_width', 'instrument_wlgrid'],
#    'holdout_rows': 64,
#    'log10_aux_columns': ['star_distance',
#     'star_mass_kg',
#     'star_radius_m',
#     'planet_mass_kg',
#     'planet_orbital_period',
#     'planet_distance',
#     'planet_surface_gravity'],
#    'model_spectral_channels': ['instrument_spectrum',
#     'instrument_noise',
#     'instrument_width_template',
#     'wavelength_um'],
#    'model_spectrum_shape': [4, 52],
#    'presence_threshold_log10_vmr': -8.0,
#    'primary_stratify_mode': 'presence_signature',
#    'raw_spectral_channels': ['instrument_spectrum',
#     'instrument_noise',
#     'instrument_width',
#     'instrument_wlgrid'],
#    'raw_spectrum_shape': [52, 4],
#    'rows_total': 41423,
#    'sample_spectral_channels': ['instrument_spectrum', 'instrument_noise'],
#    'sample_spectral_normalization': {'applied_channels': ['instrument_spectrum',
#      'instrument_noise'],
#     'mode': 'divide_by_sample_mean',
#     'reference_channel': 'instrument_spectrum'},
#    'secondary_stratify_mode': 'unstratified',
#    'shared_split_file': '/Users/jkw/Documents/uni/axion/hack4sages/ariel/models/notebooks/outputs/fair_small_compare/20260312_000541/shared_split.csv',
#    'split_fractions': {'holdout': 0.1, 'train': 0.8, 'val': 0.1},
#    'split_seed': 42,
#    'target_columns': ['log_H2O', 'log_CO2', 'log_CO', 'log_CH4', 'log_NH3'],
#    'testdata_rows': 685,
#    'testdata_rows_total': 685,
#    'train_rows': 256,
#    'val_rows': 64,
#    'wavelength_bins': 52,
#    'wavelength_max_um': 7.275559425354004,
#    'wavelength_min_um': 0.550000011920929}},
#  'stage2_summary': {'status': 'stopped_runtime',
#   'best_epoch': 6,
#   'best_val_rmse_mean': 0.9419435262680054,
#   'validation_rmse_mean': 0.9422310590744019,
#   'validation_mae_mean': 0.760151743888855,
#   'holdout_rmse_mean': 0.8886178731918335,
#   'holdout_mae_mean': 0.7159059643745422,
#   'runtime_seconds': 16.281665291004174,
#   'max_runtime_seconds': 15.80789924999408,
#   'testdata_rows': 685,
#   'output_dir': '/Users/jkw/Documents/uni/axion/hack4sages/ariel/models/notebooks/outputs/fair_small_compare/20260312_000541/codex/stage2_hybrid',
#   'dataset': {'aux_columns': ['star_distance',
#     'star_mass_kg',
#     'star_radius_m',
#     'star_temperature',
#     'planet_mass_kg',
#     'planet_orbital_period',
#     'planet_distance',
#     'planet_surface_gravity'],
#    'fixed_spectral_channels': ['instrument_width', 'instrument_wlgrid'],
#    'holdout_rows': 64,
#    'log10_aux_columns': ['star_distance',
#     'star_mass_kg',
#     'star_radius_m',
#     'planet_mass_kg',
#     'planet_orbital_period',
#     'planet_distance',
#     'planet_surface_gravity'],
#    'model_spectral_channels': ['instrument_spectrum',
#     'instrument_noise',
#     'instrument_width_template',
#     'wavelength_um'],
#    'model_spectrum_shape': [4, 52],
#    'presence_threshold_log10_vmr': -8.0,
#    'primary_stratify_mode': 'presence_signature',
#    'raw_spectral_channels': ['instrument_spectrum',
#     'instrument_noise',
#     'instrument_width',
#     'instrument_wlgrid'],
#    'raw_spectrum_shape': [52, 4],
#    'rows_total': 41423,
#    'sample_spectral_channels': ['instrument_spectrum', 'instrument_noise'],
#    'sample_spectral_normalization': {'applied_channels': ['instrument_spectrum',
#      'instrument_noise'],
#     'mode': 'divide_by_sample_mean',
#     'reference_channel': 'instrument_spectrum'},
#    'secondary_stratify_mode': 'unstratified',
#    'shared_split_file': '/Users/jkw/Documents/uni/axion/hack4sages/ariel/models/notebooks/outputs/fair_small_compare/20260312_000541/shared_split.csv',
#    'split_fractions': {'holdout': 0.1, 'train': 0.8, 'val': 0.1},
#    'split_seed': 42,
#    'target_columns': ['log_H2O', 'log_CO2', 'log_CO', 'log_CH4', 'log_NH3'],
#    'testdata_rows': 685,
#    'testdata_rows_total': 685,
#    'train_rows': 256,
#    'val_rows': 64,
#    'wavelength_bins': 52,
#    'wavelength_max_um': 7.275559425354004,
#    'wavelength_min_um': 0.550000011920929}}}

# %%
FMPE_OUTPUT_DIR = OUTPUT_ROOT / "fmpe"
if FMPE_OUTPUT_DIR.exists():
    shutil.rmtree(FMPE_OUTPUT_DIR)
FMPE_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

fmpe_settings = yaml.safe_load((PROJECT_ROOT / "models" / "sbi_ariel_adc2023" / "settings" / "adc2023_rtx4090.yaml").read_text())
fmpe_settings["dataset"]["path"] = str(FMPE_PREPARED_DIR)
fmpe_settings["training"]["device"] = "cpu"
fmpe_settings["training"]["batch_size"] = FMPE_BATCH_SIZE
fmpe_settings["training"]["eval_batch_size"] = FMPE_EVAL_BATCH_SIZE
fmpe_settings["training"]["epochs"] = FMPE_MAX_EPOCHS
fmpe_settings["training"]["patience"] = FMPE_PATIENCE
fmpe_settings["training"]["checkpoint_every_batches"] = 5
fmpe_settings["training"]["num_workers"] = 0
fmpe_settings["training"]["pin_memory"] = False
fmpe_settings["training"]["persistent_workers"] = False
fmpe_settings["training"]["prefetch_factor"] = None
fmpe_settings["training"]["max_steps"] = FMPE_MAX_STEPS
fmpe_settings["training"]["max_runtime_seconds"] = FMPE_MAX_RUNTIME_SECONDS
fmpe_settings["evaluation"]["device"] = "cpu"
fmpe_settings["evaluation"]["run_after_training"] = False
fmpe_settings["evaluation"]["posterior_samples"] = FMPE_POSTERIOR_SAMPLES
fmpe_settings["evaluation"]["context_batch_size"] = FMPE_CONTEXT_BATCH_SIZE
fmpe_settings["evaluation"]["progress_every_batches"] = 10
fmpe_settings["evaluation"]["periodic_rmse_every_epochs"] = 1
fmpe_settings["evaluation"]["periodic_posterior_samples"] = FMPE_PERIODIC_SAMPLES
fmpe_settings["evaluation"]["periodic_context_batch_size"] = FMPE_CONTEXT_BATCH_SIZE
fmpe_settings["evaluation"]["periodic_rmse_max_rows"] = 0
fmpe_settings["logging"]["use_wandb"] = False
fmpe_settings["task"]["name"] = f"adc2023_fair_small_compare_{RUN_TAG}"

fmpe_training_summary = train_model(
    settings=fmpe_settings,
    run_dir=FMPE_OUTPUT_DIR,
    prepared_data_override=FMPE_PREPARED_DIR,
    resume_mode="never",
)
print(json.dumps(fmpe_training_summary, indent=2, sort_keys=True))

fmpe_eval_outputs = run_regression_evaluation(
    settings=fmpe_settings,
    run_dir=FMPE_OUTPUT_DIR,
    prepared_data_override=FMPE_PREPARED_DIR,
)
print(json.dumps(fmpe_eval_outputs, indent=2, sort_keys=True))

validation_metrics = json.loads((FMPE_OUTPUT_DIR / "validation_regression_metrics.json").read_text())
holdout_metrics = json.loads((FMPE_OUTPUT_DIR / "holdout_regression_metrics.json").read_text())
posterior_selection = json.loads((FMPE_OUTPUT_DIR / "posterior_selection.json").read_text())
point_estimate_mode = posterior_selection["selected_point_estimate"]
fmpe_result = {
    "model": "sota_fmpe",
    "selected_point_estimate": point_estimate_mode,
    "best_epoch": int(fmpe_training_summary["best_epoch"]),
    "best_val_loss": float(fmpe_training_summary["best_val_loss"]),
    "validation_rmse_mean": float(validation_metrics[point_estimate_mode]["rmse_mean"]),
    "holdout_rmse_mean": float(holdout_metrics[point_estimate_mode]["rmse_mean"]),
    "validation_rmse": {name: float(value) for name, value in validation_metrics[point_estimate_mode]["rmse"].items()},
    "holdout_rmse": {name: float(value) for name, value in holdout_metrics[point_estimate_mode]["rmse"].items()},
    "training_summary": fmpe_training_summary,
    "evaluation_outputs": fmpe_eval_outputs,
}
(FMPE_OUTPUT_DIR / "summary.json").write_text(json.dumps(fmpe_result, indent=2, sort_keys=True) + "\n")
fmpe_result
# Out:
# Putting posterior model to device cpu.
# Max runtime seconds: 20.0
# Start training epoch 1 on cpu.
# Epoch 1 complete | train_loss=1.914372 val_loss=1.857651 lr=4.999452e-04 best_val_loss=inf best_rmse=n/a
# Epoch 1 RMSE monitor | device=cpu rows=64/64 posterior_samples=16
# Epoch 1 RMSE | mean=1.342119 median=1.373579 rows=64 samples=16 device=cpu
# Start training epoch 2 on cpu.
# Epoch 2 complete | train_loss=1.801665 val_loss=1.774571 lr=4.997807e-04 best_val_loss=1.857651 best_rmse=1.342119
# Epoch 2 RMSE monitor | device=cpu rows=64/64 posterior_samples=16
# Epoch 2 RMSE | mean=1.342524 median=1.381976 rows=64 samples=16 device=cpu
# Runtime budget reached before starting the next epoch.
# {
#   "best_epoch": 2,
#   "best_model_by_loss_path": "/Users/jkw/Documents/uni/axion/hack4sages/ariel/models/notebooks/outputs/fair_small_compare/20260312_000541/fmpe/best_model_by_loss.pt",
#   "best_model_by_mrmse_path": "/Users/jkw/Documents/uni/axion/hack4sages/ariel/models/notebooks/outputs/fair_small_compare/20260312_000541/fmpe/best_model_by_mrmse.pt",
#   "best_model_path": "/Users/jkw/Documents/uni/axion/hack4sages/ariel/models/notebooks/outputs/fair_small_compare/20260312_000541/fmpe/best_model.pt",
#   "best_monitor_epoch": 1,
#   "best_monitor_estimator": "mean",
#   "best_monitor_rmse_mean": 1.3421192169189453,
#   "best_val_loss": 1.774571418762207,
#   "evaluation_outputs": {},
#   "global_step": 8,
#   "max_runtime_seconds": 20.0,
#   "next_epoch": 3,
#   "resume_checkpoint": "/Users/jkw/Documents/uni/axion/hack4sages/ariel/models/notebooks/outputs/fair_small_compare/20260312_000541/fmpe/resume_latest.pt",
#   "run_dir": "/Users/jkw/Documents/uni/axion/hack4sages/ariel/models/notebooks/outputs/fair_small_compare/20260312_000541/fmpe",
#   "run_final_evaluation": false,
#   "runtime_seconds": 36.67959966700437,
#   "status": "stopped_runtime"
# }
# Putting posterior model to device cpu.
# validation final evaluation: evaluating 64 rows with 32 posterior samples in 4 batches on cpu.
# validation final evaluation: batch 4/4
# holdout final evaluation: evaluating 64 rows with 32 posterior samples in 4 batches on cpu.

# %%
comparison_df = pd.DataFrame(
    [
        {
            "model": codex_result["model"],
            "validation_rmse_mean": codex_result["validation_rmse_mean"],
            "holdout_rmse_mean": codex_result["holdout_rmse_mean"],
            "notes": (
                f"two_stage, qubits={CODEX_QNN_QUBITS}, runtime_budget_s={FAIR_RUNTIME_BUDGET_SECONDS:.1f}, "
                f"stage1_status={codex_stage1_result['summary']['status']}, stage2_status={codex_stage2_result['summary']['status']}"
            ),
        },
        {
            "model": fmpe_result["model"],
            "validation_rmse_mean": fmpe_result["validation_rmse_mean"],
            "holdout_rmse_mean": fmpe_result["holdout_rmse_mean"],
            "notes": (
                f"point_estimate={fmpe_result['selected_point_estimate']}, runtime_budget_s={FMPE_MAX_RUNTIME_SECONDS:.1f}, "
                f"status={fmpe_training_summary['status']}"
            ),
        },
    ]
).sort_values("holdout_rmse_mean", ascending=True, ignore_index=True)
winner = comparison_df.iloc[0]
comparison_summary = {
    "winner": winner["model"],
    "comparison": comparison_df.to_dict(orient="records"),
    "shared_split_file": str(SHARED_SPLIT_PATH),
    "shared_split_manifest": str(OUTPUT_ROOT / "shared_split_manifest.json"),
    "codex_prepared_cache_dir": str(CODEX_PREPARED_CACHE_DIR),
    "codex_output_root": str(CODEX_OUTPUT_ROOT),
    "fmpe_prepared_dir": str(FMPE_PREPARED_DIR),
    "fmpe_output_dir": str(FMPE_OUTPUT_DIR),
}
(OUTPUT_ROOT / "comparison_summary.json").write_text(json.dumps(comparison_summary, indent=2, sort_keys=True) + "\n")

display(comparison_df)
print(f"Winner on holdout mean RMSE: {winner['model']}")
print(f"Comparison summary: {OUTPUT_ROOT / 'comparison_summary.json'}")
